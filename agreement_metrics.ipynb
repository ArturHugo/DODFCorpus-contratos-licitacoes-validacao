# %%
import pandas as pd
import numpy as np
import itertools

# %%
csv_filename = f'DODFCorpus_contratos_licitacoes_concordancia.csv'
df = pd.read_csv(csv_filename, index_col=[0])
df
# Out:
#        id_dodf          tipo_ent  id_ent       anotador_ent  offset  length  \
# 0          672  EXTRATO_CONTRATO       1  anotador_59684932      23    1227
# 1          672  EXTRATO_CONTRATO       2  anotador_69243565      23    1227
# 2          672  EXTRATO_CONTRATO       3  anotador_72589596      23    1227
# 3          672      processo_gdf       5  anotador_69243565      53      15
# 4          672      processo_gdf       6  anotador_72589596      53      15
# ...        ...               ...     ...                ...     ...     ...
# 27738      638  objeto_licitacao    3737  anotador_37219154  210322     367
# 27739      638   orgao_licitante    3738  anotador_37219154  210631      58
# 27740      638   orgao_licitante    3739  anotador_27589498  210631      58
# 27741      638  nome_responsavel    3740  anotador_37219154  210768      25
# 27742      638  nome_responsavel    3741  anotador_27589498  210769      24
#
#                                                    texto
# 0      EXTRATO DE CONTRATO Processo: 001-000853/2019....
# 1      EXTRATO DE CONTRATO Processo: 001-000853/2019....
# 2      EXTRATO DE CONTRATO Processo: 001-000853/2019....
# 3                                        001-000853/2019
# 4                                        001-000853/2019
# ...                                                  ...
# 27738  Registro de Preços para contratação de empresa...
# 27739  Secretaria de Estado do Trabalho Distrito Fede...
# 27740  Secretaria de Estado do Trabalho Distrito Fede...
# 27741                          JUNILMA OLIVEIRA FERREIRA
# 27742                           UNILMA OLIVEIRA FERREIRA
#
# [27743 rows x 7 columns]

# %%
# Divide o dataframe for DODF

id_dodfs = df['id_dodf'].unique()

# Chave = id_dodf, valor = dataframe com as anotacoes do dodf
dodf_dataframes = {}

for id_dodf in id_dodfs:
    dodf_dataframes[id_dodf] = df[df['id_dodf'] == id_dodf]

dodf_dataframes[id_dodfs[0]]
# Out:
#       id_dodf                  tipo_ent  id_ent       anotador_ent  offset  \
# 0         672          EXTRATO_CONTRATO       1  anotador_59684932      23
# 1         672          EXTRATO_CONTRATO       2  anotador_69243565      23
# 2         672          EXTRATO_CONTRATO       3  anotador_72589596      23
# 3         672              processo_gdf       5  anotador_69243565      53
# 4         672              processo_gdf       6  anotador_72589596      53
# ...       ...                       ...     ...                ...     ...
# 2270      672         vigencia_contrato    2375  anotador_59684932  166035
# 2271      672         vigencia_contrato    2376  anotador_69243565  166035
# 2272      672  data_assinatura_contrato    2377  anotador_72589596  166103
# 2273      672  data_assinatura_contrato    2378  anotador_59684932  166103
# 2274      672  data_assinatura_contrato    2379  anotador_69243565  166103
#
#       length                                              texto
# 0       1227  EXTRATO DE CONTRATO Processo: 001-000853/2019....
# 1       1227  EXTRATO DE CONTRATO Processo: 001-000853/2019....
# 2       1227  EXTRATO DE CONTRATO Processo: 001-000853/2019....
# 3         15                                    001-000853/2019
# 4         15                                    001-000853/2019
# ...      ...                                                ...
# 2270      46     12 (doze) meses a contar da data de assinatura
# 2271      46     12 (doze) meses a contar da data de assinatura
# 2272      10                                         25/07/2019
# 2273      10                                         25/07/2019
# 2274      10                                         25/07/2019
#
# [2275 rows x 7 columns]

# %% [markdown]
# Para cada DODF, são agrupadas as anotações referentes a uma mesma entidade feias por anotadores diferetes.
# Os critérios para determinar se uma anotação é referente à mesma entidade que uma anotação tomada como base (critérios de pertinência) são:
#
# 1. O offset de início das duas anotações são iguais com uma margem de caracteres de 10% do tamanho da anotação base;
#
# 2. Os tamanhos das duas anotações são iguais com uma margem de 10%.

# %%
# Agrupa as anotacoes pertinentes a uma mesma entidade

# Chave = id_dodf
# Valor = lista de conjuntos de anotacoes que se referem a uma mesma entidade
dodf_annotation_groups = {}

for id_dodf in id_dodfs:
    df = dodf_dataframes[id_dodf]
    dodf_annotation_groups[id_dodf] = []

    # Chave = indice de uma anotacao do dataframe
    # Valor = lista de indices de anotacoes que satisfazem os criterios de pertinencia
    # em relacao a anotacao da chave.
    annotation_groups_redundant = {}
    for index in df.index:
        base_annotation = df.loc[index]
        base_offset = base_annotation['offset']
        base_length = base_annotation['length']
        
        # Primeiro criterio
        # TODO aplicar o bonus de tolerancia para entidades menores que nem para length
        # TODO testar com +/- (0.1+13/base_length)*base_length
        # esse valor abrange o caso de "prestação de serviços" vs "serviços"
        min_offset  = base_offset-(0.1+13/base_length)*base_length
        max_offset  = base_offset+(0.1+13/base_length)*base_length
        annotations = df[(df['offset'] > min_offset) & (df['offset'] < max_offset)]

        # Segundo criterio
        # TODO testar 23 no lugar do 6
        # esse valor abrange o caso de "prestação de serviços" vs "serviços"
        min_length  = base_length-(0.1+23/base_length)*base_length
        max_length  = base_length+(0.1+23/base_length)*base_length
        annotations = annotations[(annotations['length'] > min_length) & (annotations['length'] < max_length)]
        
        annotation_groups_redundant[index] = list(annotations.index)

    # Para remover os grupos redundantes, converte-se o dicionario para uma lista de sets.
    # Cada set contem o indice usado como chave e os indices da sua lista de valores.
    for key_annotation, annotation_list in annotation_groups_redundant.items():
        annotation_list.append(key_annotation)
        dodf_annotation_groups[id_dodf].append(frozenset(annotation_list))

    dodf_annotation_groups[id_dodf] = set(dodf_annotation_groups[id_dodf])


dodf_annotation_groups[id_dodfs[1]]
# Out:
# {frozenset({4333, 4334}),
#  frozenset({3717}),
#  frozenset({2416, 2417, 2420}),
#  frozenset({3313}),
#  frozenset({3287}),
#  frozenset({2909, 2910, 2911}),
#  frozenset({2294, 2295, 2296}),
#  frozenset({3618}),
#  frozenset({3729, 3730}),
#  frozenset({3871, 3872, 3873}),
#  frozenset({4132, 4133}),
#  frozenset({4160, 4161}),
#  frozenset({4269, 4271, 4273}),
#  frozenset({4365, 4366, 4367}),
#  frozenset({3288, 3289}),
#  frozenset({4404, 4405}),
#  frozenset({3510, 3511, 3512}),
#  frozenset({4320, 4321}),
#  frozenset({3435}),
#  frozenset({3436}),
#  frozenset({4454, 4455}),
#  frozenset({3126, 3127}),
#  frozenset({3005, 3006, 3007}),
#  frozenset({3437}),
#  frozenset({4294, 4295}),
#  frozenset({2834, 2835, 2836}),
#  frozenset({2694, 2695}),
#  frozenset({4140, 4141}),
#  frozenset({2421, 2422}),
#  frozenset({2792, 2793, 2794}),
#  frozenset({2933, 2934, 2935}),
#  frozenset({3981, 3982}),
#  frozenset({2938, 2939, 2940}),
#  frozenset({3892, 3893}),
#  frozenset({2413, 2414, 2415}),
#  frozenset({3962, 3963, 3964}),
#  frozenset({4369, 4370, 4371}),
#  frozenset({3025, 3026}),
#  frozenset({3464, 3465, 3466}),
#  frozenset({2570, 2571, 2572}),
#  frozenset({4452, 4453}),
#  frozenset({2493, 2494}),
#  frozenset({2770, 2771, 2772}),
#  frozenset({3433}),
#  frozenset({3852, 3853, 3854}),
#  frozenset({2822, 2823}),
#  frozenset({4247}),
#  frozenset({4323, 4324}),
#  frozenset({2997, 2998, 2999}),
#  frozenset({4255, 4256, 4257}),
#  frozenset({2349, 2350, 2351}),
#  frozenset({2790, 2791}),
#  frozenset({2661}),
#  frozenset({3933}),
#  frozenset({2285, 2286, 2287}),
#  frozenset({3107, 3108, 3109}),
#  frozenset({3461, 3462, 3463}),
#  frozenset({3947, 3948}),
#  frozenset({3970, 3971, 3972}),
#  frozenset({3774, 3775}),
#  frozenset({3565, 3566, 3567}),
#  frozenset({3029, 3030}),
#  frozenset({4075}),
#  frozenset({3440, 3441, 3442}),
#  frozenset({4379, 4380, 4381}),
#  frozenset({2597, 2598}),
#  frozenset({3768, 3769}),
#  frozenset({4397, 4398}),
#  frozenset({3929, 3930}),
#  frozenset({2562, 2563}),
#  frozenset({2524}),
#  frozenset({3033, 3034}),
#  frozenset({3092, 3093, 3094}),
#  frozenset({2553, 2554, 2555}),
#  frozenset({3058, 3059}),
#  frozenset({2535, 2536}),
#  frozenset({2386, 2387}),
#  frozenset({2760, 2761, 2762}),
#  frozenset({3024}),
#  frozenset({3132, 3133}),
#  frozenset({3265, 3266, 3267}),
#  frozenset({4037, 4038}),
#  frozenset({4154, 4155}),
#  frozenset({4406, 4407}),
#  frozenset({4110, 4111}),
#  frozenset({3294, 3295}),
#  frozenset({3039, 3040}),
#  frozenset({3232}),
#  frozenset({3244}),
#  frozenset({3262, 3263, 3264}),
#  frozenset({3298, 3299}),
#  frozenset({4290, 4291}),
#  frozenset({3989, 3990}),
#  frozenset({2584, 2585, 2586}),
#  frozenset({2824, 2825, 2826}),
#  frozenset({3555, 3556, 3557}),
#  frozenset({3700, 3701, 3702}),
#  frozenset({3764}),
#  frozenset({3927, 3928}),
#  frozenset({2276}),
#  frozenset({3116, 3117, 3118}),
#  frozenset({4244, 4245, 4246}),
#  frozenset({3072}),
#  frozenset({3874, 3875, 3876}),
#  frozenset({3380, 3381, 3382}),
#  frozenset({3189, 3190, 3191}),
#  frozenset({4325, 4326}),
#  frozenset({3242}),
#  frozenset({4263, 4264, 4265}),
#  frozenset({4464, 4465}),
#  frozenset({3351, 3352, 3353}),
#  frozenset({3335, 3336, 3337}),
#  frozenset({4241, 4242, 4243}),
#  frozenset({2990, 2991, 2992}),
#  frozenset({2968, 2969}),
#  frozenset({2395, 2396}),
#  frozenset({2635, 2636}),
#  frozenset({2656, 2658, 2660}),
#  frozenset({2766, 2767, 2768}),
#  frozenset({3965, 3966, 3967}),
#  frozenset({2330}),
#  frozenset({4315}),
#  frozenset({4021, 4022}),
#  frozenset({4460, 4461}),
#  frozenset({3361}),
#  frozenset({2731, 2732, 2733}),
#  frozenset({3477, 3478}),
#  frozenset({2409}),
#  frozenset({3831, 3832, 3833}),
#  frozenset({4112, 4113}),
#  frozenset({2588, 2589}),
#  frozenset({3884, 3885, 3886}),
#  frozenset({2958, 2959, 2960}),
#  frozenset({3200, 3201}),
#  frozenset({3458, 3459, 3460}),
#  frozenset({3711, 3712}),
#  frozenset({4144, 4145}),
#  frozenset({3268, 3269, 3270}),
#  frozenset({3697, 3698, 3699}),
#  frozenset({3135, 3137}),
#  frozenset({2821}),
#  frozenset({3985, 3986}),
#  frozenset({3163}),
#  frozenset({4353, 4354}),
#  frozenset({4261, 4262}),
#  frozenset({3323, 3324, 3325}),
#  frozenset({3497, 3498, 3499}),
#  frozenset({3389, 3390, 3391}),
#  frozenset({3736}),
#  frozenset({3839, 3840}),
#  frozenset({3332, 3333, 3334}),
#  frozenset({4419}),
#  frozenset({3452, 3453, 3455}),
#  frozenset({3485, 3486}),
#  frozenset({2512, 2513}),
#  frozenset({2470, 2471, 2472}),
#  frozenset({3545, 3546}),
#  frozenset({3491, 3492}),
#  frozenset({2734, 2735, 2736}),
#  frozenset({2529, 2530}),
#  frozenset({2616, 2617}),
#  frozenset({3234, 3235}),
#  frozenset({3834, 3836, 3838}),
#  frozenset({4206, 4207}),
#  frozenset({4415, 4417}),
#  frozenset({3658, 3659}),
#  frozenset({2481, 2483}),
#  frozenset({3939, 3940}),
#  frozenset({4091, 4092}),
#  frozenset({2976, 2979}),
#  frozenset({2753, 2754, 2756}),
#  frozenset({4296, 4297}),
#  frozenset({2856, 2857, 2858}),
#  frozenset({4347, 4348}),
#  frozenset({3823, 3824}),
#  frozenset({3366, 3367, 3368}),
#  frozenset({2487, 2488}),
#  frozenset({3140}),
#  frozenset({3608, 3609, 3610}),
#  frozenset({4041, 4042}),
#  frozenset({4031, 4032}),
#  frozenset({3650, 3651}),
#  frozenset({2372, 2373}),
#  frozenset({2518, 2519}),
#  frozenset({4120, 4121}),
#  frozenset({3825, 3826, 3827}),
#  frozenset({2503, 2504}),
#  frozenset({2784, 2787}),
#  frozenset({2749, 2750, 2751}),
#  frozenset({2514, 2515}),
#  frozenset({2282, 2283, 2284}),
#  frozenset({4432, 4433}),
#  frozenset({3176, 3177, 3178}),
#  frozenset({4226, 4227, 4228}),
#  frozenset({2810, 2811, 2812}),
#  frozenset({3346, 3347, 3348}),
#  frozenset({3828, 3829, 3830}),
#  frozenset({2465, 2466, 2467}),
#  frozenset({2913, 2915, 2916}),
#  frozenset({4158, 4159}),
#  frozenset({3134, 3136}),
#  frozenset({3077, 3078, 3079}),
#  frozenset({3169}),
#  frozenset({2376, 2377}),
#  frozenset({3398, 3399, 3400}),
#  frozenset({3308}),
#  frozenset({4003, 4004}),
#  frozenset({3579, 3580, 3581}),
#  frozenset({2559, 2560, 2561}),
#  frozenset({3417, 3418, 3419}),
#  frozenset({3205, 3206, 3207}),
#  frozenset({3423, 3424, 3425}),
#  frozenset({4103, 4104}),
#  frozenset({4156, 4157}),
#  frozenset({2599, 2600, 2601}),
#  frozenset({3902, 3903}),
#  frozenset({4136, 4137}),
#  frozenset({4395, 4396}),
#  frozenset({2410, 2411, 2412}),
#  frozenset({3639}),
#  frozenset({4009, 4010}),
#  frozenset({4011, 4012}),
#  frozenset({2629, 2630}),
#  frozenset({3431}),
#  frozenset({4175}),
#  frozenset({4258, 4259, 4260}),
#  frozenset({3326, 3327, 3328}),
#  frozenset({3614, 3615, 3616}),
#  frozenset({4061, 4062}),
#  frozenset({4238, 4239, 4240}),
#  frozenset({4384, 4385}),
#  frozenset({3101, 3102, 3103}),
#  frozenset({3066}),
#  frozenset({2982, 2983}),
#  frozenset({3500, 3501}),
#  frozenset({3404}),
#  frozenset({2693}),
#  frozenset({3229}),
#  frozenset({3253, 3254, 3255}),
#  frozenset({4005, 4006}),
#  frozenset({2757}),
#  frozenset({4013, 4014}),
#  frozenset({2318, 2319, 2320}),
#  frozenset({4252, 4253, 4254}),
#  frozenset({3239, 3240}),
#  frozenset({3482, 3484}),
#  frozenset({2773, 2774, 2775}),
#  frozenset({3810, 3812}),
#  frozenset({3900, 3901}),
#  frozenset({2702, 2703, 2704}),
#  frozenset({3640, 3641}),
#  frozenset({2720, 2722, 2723}),
#  frozenset({3787, 3788}),
#  frozenset({2918, 2919}),
#  frozenset({2627, 2628}),
#  frozenset({4001, 4002}),
#  frozenset({4059, 4060}),
#  frozenset({2981}),
#  frozenset({3660, 3661, 3662}),
#  frozenset({3202, 3203, 3204}),
#  frozenset({2499, 2500}),
#  frozenset({3300, 3301}),
#  frozenset({4349, 4350}),
#  frozenset({3626, 3627, 3628}),
#  frozenset({3383, 3384, 3385}),
#  frozenset({2872, 2873}),
#  frozenset({3776, 3777}),
#  frozenset({3995, 3996}),
#  frozenset({4049, 4050}),
#  frozenset({2613, 2614, 2615}),
#  frozenset({3317, 3318, 3319}),
#  frozenset({4343, 4344}),
#  frozenset({2380, 2381}),
#  frozenset({2426, 2427, 2428}),
#  frozenset({3145}),
#  frozenset({3688, 3689, 3690}),
#  frozenset({3645, 3646}),
#  frozenset({4436, 4437}),
#  frozenset({2781, 2782, 2783}),
#  frozenset({4309, 4310}),
#  frozenset({4408, 4409}),
#  frozenset({3060, 3061}),
#  frozenset({2994, 2995, 2996}),
#  frozenset({4198, 4199}),
#  frozenset({4087, 4088, 4090}),
#  frozenset({2631, 2632}),
#  frozenset({2537, 2538}),
#  frozenset({2578, 2579, 2581}),
#  frozenset({3731, 3732}),
#  frozenset({4280, 4281, 4282}),
#  frozenset({2309, 2310, 2311}),
#  frozenset({3445, 3446, 3447}),
#  frozenset({4236}),
#  frozenset({3358, 3359, 3360}),
#  frozenset({2970, 2971, 2972}),
#  frozenset({2888, 2889, 2890}),
#  frozenset({4114, 4115}),
#  frozenset({2505, 2506}),
#  frozenset({3528, 3529}),
#  frozenset({2279, 2280, 2281}),
#  frozenset({3673, 3674, 3675}),
#  frozenset({3158, 3159, 3160}),
#  frozenset({3866}),
#  frozenset({2418, 2419}),
#  frozenset({2288, 2289, 2290}),
#  frozenset({2917}),
#  frozenset({3290, 3291}),
#  frozenset({4150, 4151}),
#  frozenset({3652, 3653, 3654}),
#  frozenset({2459, 2460, 2461}),
#  frozenset({3814}),
#  frozenset({3959, 3960, 3961}),
#  frozenset({3070}),
#  frozenset({2705}),
#  frozenset({2312, 2313, 2314}),
#  frozenset({2366}),
#  frozenset({2625, 2626}),
#  frozenset({2778, 2779, 2780}),
#  frozenset({4186, 4187}),
#  frozenset({4105, 4106, 4107}),
#  frozenset({2961}),
#  frozenset({3251, 3252}),
#  frozenset({3997, 3998}),
#  frozenset({4163, 4164}),
#  frozenset({3691, 3692, 3693}),
#  frozenset({3080, 3081, 3082}),
#  frozenset({3432}),
#  frozenset({3043, 3044}),
#  frozenset({4391, 4392}),
#  frozenset({3217, 3218}),
#  frozenset({3015, 3016, 3017}),
#  frozenset({3765, 3766}),
#  frozenset({4070, 4071, 4072}),
#  frozenset({4335, 4336}),
#  frozenset({4434, 4435}),
#  frozenset({4223, 4224, 4225}),
#  frozenset({2859, 2860, 2861}),
#  frozenset({3540}),
#  frozenset({4063, 4064, 4065}),
#  frozenset({3073}),
#  frozenset({2776, 2777}),
#  frozenset({3762, 3763}),
#  frozenset({2817, 2819, 2820}),
#  frozenset({3605, 3606, 3607}),
#  frozenset({2408}),
#  frozenset({3518, 3519}),
#  frozenset({3795, 3796}),
#  frozenset({3881, 3882, 3883}),
#  frozenset({2689, 2691}),
#  frozenset({3634, 3635, 3637}),
#  frozenset({2973, 2974, 2975}),
#  frozenset({4403}),
#  frozenset({3341, 3342, 3343}),
#  frozenset({3664, 3667}),
#  frozenset({3956, 3957, 3958}),
#  frozenset({2510, 2511}),
#  frozenset({3011, 3012, 3013}),
#  frozenset({4066, 4067, 4068}),
#  frozenset({4192, 4193}),
#  frozenset({2853}),
#  frozenset({4169, 4170}),
#  frozenset({4428, 4429}),
#  frozenset({3095, 3096, 3097}),
#  frozenset({3945}),
#  frozenset({3075}),
#  frozenset({4305, 4306}),
#  frozenset({2789}),
#  frozenset({4339, 4340}),
#  frozenset({3894}),
#  frozenset({4073, 4074}),
#  frozenset({3591, 3592}),
#  frozenset({2545, 2546}),
#  frozenset({2805, 2806, 2807}),
#  frozenset({2608, 2609, 2610}),
#  frozenset({3513, 3514}),
#  frozenset({3611, 3612, 3613}),
#  frozenset({2650, 2651, 2652}),
#  frozenset({2865}),
#  frozenset({3725, 3726}),
#  frozenset({3912, 3913}),
#  frozenset({4330, 4331, 4332}),
#  frozenset({3574, 3575}),
#  frozenset({2343, 2344, 2345}),
#  frozenset({2442, 2443, 2444}),
#  frozenset({2920, 2921, 2922}),
#  frozenset({3620}),
#  frozenset({2813, 2814, 2815}),
#  frozenset({4274}),
#  frozenset({2450, 2451, 2452}),
#  frozenset({2912, 2914}),
#  frozenset({2388, 2389}),
#  frozenset({3420, 3421, 3422}),
#  frozenset({4182, 4183}),
#  frozenset({3493, 3494}),
#  frozenset({2637, 2638}),
#  frozenset({3047, 3048}),
#  frozenset({4298, 4299, 4300}),
#  frozenset({3536, 3537}),
#  frozenset({4393, 4394}),
#  frozenset({4007, 4008}),
#  frozenset({2795, 2796, 2797}),
#  frozenset({3669}),
#  frozenset({3241, 3243}),
#  frozenset({3307}),
#  frozenset({3119, 3120, 3121}),
#  frozenset({3878, 3879, 3880}),
#  frozenset({3369, 3370, 3371}),
#  frozenset({4047, 4048}),
#  frozenset({3219}),
#  frozenset({4389, 4390}),
#  frozenset({4346}),
#  frozenset({3430}),
#  frozenset({2429, 2430, 2431}),
#  frozenset({2479, 2480}),
#  frozenset({2580, 2583}),
#  frozenset({2709, 2710, 2711}),
#  frozenset({3750, 3751}),
#  frozenset({2527, 2528}),
#  frozenset({3789, 3790}),
#  frozenset({3041, 3042}),
#  frozenset({3071}),
#  frozenset({3906}),
#  frozenset({4135}),
#  frozenset({4194, 4195}),
#  frozenset({3098, 3099, 3100}),
#  frozenset({3148, 3149}),
#  frozenset({2798, 2799, 2800}),
#  frozenset({3741, 3742}),
#  frozenset({3706, 3707, 3708}),
#  frozenset({3991, 3992}),
#  frozenset({3037, 3038}),
#  frozenset({3305, 3306}),
#  frozenset({3973, 3974, 3975}),
#  frozenset({3647, 3648, 3649}),
#  frozenset({3924, 3925, 3926}),
#  frozenset({3743, 3744}),
#  frozenset({3797}),
#  frozenset({4184, 4185}),
#  frozenset({3414, 3415, 3416}),
#  frozenset({4360, 4361, 4362}),
#  frozenset({4448, 4449}),
#  frozenset({2945, 2947, 2948}),
#  frozenset({2648, 2649}),
#  frozenset({4249}),
#  frozenset({2785, 2786, 2788}),
#  frozenset({3141, 3142}),
#  frozenset({4446, 4447}),
#  frozenset({3505, 3506, 3507}),
#  frozenset({3642, 3643, 3644}),
#  frozenset({3907, 3908}),
#  frozenset({2462, 2463, 2464}),
#  frozenset({3721, 3722}),
#  frozenset({2685, 2686, 2687}),
#  frozenset({3062, 3063}),
#  frozenset({3377, 3378, 3379}),
#  frozenset({4351, 4352}),
#  frozenset({3314}),
#  frozenset({2374, 2375}),
#  frozenset({2639, 2640}),
#  frozenset({3949, 3950, 3951}),
#  frozenset({4057, 4058}),
#  frozenset({4317, 4318, 4319}),
#  frozenset({3286}),
#  frozenset({2674, 2675, 2676}),
#  frozenset({4017, 4018}),
#  frozenset({4237}),
#  frozenset({4025, 4026}),
#  frozenset({4167, 4168}),
#  frozenset({4386, 4387, 4388}),
#  frozenset({2696, 2697, 2698}),
#  frozenset({3502, 3503, 3504}),
#  frozenset({3931, 3932}),
#  frozenset({3636, 3638}),
#  frozenset({2738, 2739, 2740}),
#  frozenset({4152, 4153}),
#  frozenset({3935, 3936}),
#  frozenset({3663}),
#  frozenset({2525}),
#  frozenset({3631, 3632, 3633}),
#  frozenset({4478, 4479}),
#  frozenset({2657, 2659}),
#  frozenset({3617}),
#  frozenset({3338, 3339, 3340}),
#  frozenset({3173, 3174, 3175}),
#  frozenset({3220, 3221}),
#  frozenset({3806, 3807}),
#  frozenset({3815}),
#  frozenset({4196, 4197}),
#  frozenset({3534, 3535}),
#  frozenset({3783, 3784}),
#  frozenset({4100, 4101, 4102}),
#  frozenset({3576, 3577, 3578}),
#  frozenset({2886, 2887}),
#  frozenset({2384, 2385}),
#  frozenset({2769}),
#  frozenset({2837, 2838, 2839}),
#  frozenset({2891, 2892, 2893}),
#  frozenset({3489, 3490}),
#  frozenset({3434}),
#  frozenset({3395, 3396, 3397}),
#  frozenset({2965, 2966, 2967}),
#  frozenset({3770, 3771}),
#  frozenset({3917}),
#  frozenset({3859, 3860}),
#  frozenset({3192, 3193, 3194}),
#  frozenset({3999, 4000}),
#  frozenset({4420, 4421}),
#  frozenset({4275, 4276}),
#  frozenset({4311}),
#  frozenset({3655, 3656, 3657}),
#  frozenset({3052, 3053}),
#  frozenset({2936, 2937}),
#  frozenset({2816, 2818}),
#  frozenset({3275}),
#  frozenset({3899}),
#  frozenset({3820, 3821, 3822}),
#  frozenset({4190, 4191}),
#  frozenset({3791, 3792}),
#  frozenset({3541}),
#  frozenset({3150, 3151, 3152}),
#  frozenset({3715, 3716}),
#  frozenset({3283, 3284, 3285}),
#  frozenset({3167, 3168}),
#  frozenset({3802, 3803}),
#  frozenset({4372}),
#  frozenset({2877, 2878, 2879}),
#  frozenset({2440, 2441}),
#  frozenset({3520, 3521}),
#  frozenset({3214, 3215, 3216}),
#  frozenset({3818, 3819}),
#  frozenset({2677, 2678, 2679}),
#  frozenset({2453, 2454, 2456}),
#  frozenset({2522, 2523}),
#  frozenset({3993, 3994}),
#  frozenset({2591, 2592, 2593}),
#  frozenset({3329, 3330, 3331}),
#  frozenset({4128, 4129}),
#  frozenset({2448}),
#  frozenset({3161}),
#  frozenset({2564, 2565}),
#  frozenset({2721, 2724}),
#  frozenset({3401, 3402, 3403}),
#  frozenset({2371}),
#  frozenset({3861, 3862}),
#  frozenset({3887, 3888, 3889}),
#  frozenset({4345}),
#  frozenset({4376, 4377, 4378}),
#  frozenset({3110, 3111, 3112}),
#  frozenset({3911}),
#  frozenset({2906, 2907, 2908}),
#  frozenset({2849, 2851, 2852}),
#  frozenset({3035, 3036}),
#  frozenset({3349, 3350}),
#  frozenset({2297, 2298, 2299}),
#  frozenset({3068}),
#  frozenset({4450, 4451}),
#  frozenset({2489, 2490}),
#  frozenset({3522, 3523, 3524}),
#  frozenset({2526}),
#  frozenset({2457, 2458}),
#  frozenset({2346, 2347, 2348}),
#  frozenset({3138, 3139}),
#  frozenset({2672}),
#  frozenset({4359}),
#  frozenset({2291, 2292, 2293}),
#  frozenset({2930, 2931, 2932}),
#  frozenset({4210, 4211}),
#  frozenset({2744, 2745}),
#  frozenset({3865}),
#  frozenset({2894, 2895, 2896}),
#  frozenset({3525, 3526, 3527}),
#  frozenset({4176, 4177}),
#  frozenset({2445, 2446, 2447}),
#  frozenset({2869, 2870, 2871}),
#  frozenset({4178, 4179}),
#  frozenset({4418}),
#  frozenset({2507}),
#  frozenset({2382, 2383}),
#  frozenset({3530, 3531}),
#  frozenset({2590}),
#  frozenset({2653, 2654, 2655}),
#  frozenset({4098, 4099}),
#  frozenset({2547}),
#  frozenset({3233}),
#  frozenset({3227, 3228}),
#  frozenset({2862, 2863, 2864}),
#  frozenset({3676, 3677, 3678}),
#  frozenset({4069}),
#  frozenset({3782}),
#  frozenset({3473, 3474}),
#  frozenset({4043, 4044}),
#  frozenset({4208, 4209}),
#  frozenset({2801}),
#  frozenset({3429}),
#  frozenset({3162}),
#  frozenset({2369}),
#  frozenset({3798, 3799}),
#  frozenset({3311}),
#  frozenset({2880, 2882}),
#  frozenset({2364}),
#  frozenset({4316}),
#  frozenset({4414, 4416}),
#  frozenset({3247}),
#  frozenset({2926, 2927, 2928}),
#  frozenset({3256, 3257, 3258}),
#  frozenset({2550, 2551, 2552}),
#  frozenset({4212, 4213}),
#  frozenset({4250}),
#  frozenset({4468, 4469}),
#  frozenset({2455}),
#  frozenset({2300, 2301, 2302}),
#  frozenset({2516, 2517}),
#  frozenset({2352, 2353, 2354}),
#  frozenset({3236, 3237}),
#  frozenset({2618, 2619, 2620}),
#  frozenset({3195, 3197}),
#  frozenset({3835, 3837}),
#  frozenset({4422, 4423}),
#  frozenset({3793, 3794}),
#  frozenset({2580, 2582, 2583}),
#  frozenset({3320, 3321, 3322}),
#  frozenset({2533, 2534}),
#  frozenset({2688, 2690, 2692}),
#  frozenset({2541, 2542}),
#  frozenset({3842, 3843, 3844}),
#  frozenset({4214, 4215, 4216}),
#  frozenset({3225, 3226}),
#  frozenset({2714, 2715, 2716}),
#  frozenset({3569, 3570, 3571}),
#  frozenset({2340, 2341, 2342}),
#  frozenset({2901, 2902, 2903}),
#  frozenset({2566, 2567}),
#  frozenset({2962, 2963, 2964}),
#  frozenset({2949}),
#  frozenset({3550, 3551}),
#  frozenset({4116, 4117}),
#  frozenset({3375, 3376}),
#  frozenset({3625}),
#  frozenset({4146, 4147}),
#  frozenset({2645, 2646, 2647}),
#  frozenset({2327, 2328, 2329}),
#  frozenset({2355, 2356, 2357}),
#  frozenset({2468, 2469}),
#  frozenset({3045, 3046}),
#  frozenset({3357}),
#  frozenset({2434, 2435, 2436}),
#  frozenset({2881, 2883, 2884}),
#  frozenset({4204, 4205}),
#  frozenset({3243}),
#  frozenset({3952, 3953, 3954}),
#  frozenset({3222, 3223}),
#  frozenset({3737, 3738}),
#  frozenset({4118, 4119}),
#  frozenset({4251}),
#  frozenset({3146, 3147}),
#  frozenset({3051}),
#  frozenset({2477, 2478}),
#  frozenset({3918, 3919, 3920}),
#  frozenset({4424, 4425}),
#  frozenset({2950, 2951}),
#  frozenset({3309}),
#  frozenset({3585, 3586, 3587}),
#  frozenset({3128, 3129}),
#  frozenset({3208, 3209, 3210}),
#  frozenset({3362, 3363}),
#  frozenset({3772, 3773}),
#  frozenset({3021, 3022, 3023}),
#  frozenset({4039, 4040}),
#  frozenset({2315, 2316, 2317}),
#  frozenset({3184, 3185, 3186}),
#  frozenset({3543}),
#  frozenset({2977, 2978, 2980}),
#  frozenset({4458, 4459}),
#  frozenset({3588, 3589, 3590}),
#  frozenset({2664, 2665}),
#  frozenset({3076}),
#  frozenset({4235}),
#  frozenset({3983, 3984}),
#  frozenset({2394}),
#  frozenset({2758, 2759}),
#  frozenset({2840, 2841}),
#  frozenset({3718, 3719}),
#  frozenset({4426, 4427}),
#  frozenset({2324, 2325, 2326}),
#  frozenset({2400, 2401}),
#  frozenset({4270, 4272}),
#  frozenset({2368}),
#  frozenset({4292, 4293}),
#  frozenset({3448, 3449, 3450}),
#  frozenset({4124}),
#  frozenset({4355, 4356}),
#  frozenset({2365}),
#  frozenset({2390, 2391}),
#  frozenset({3008, 3009, 3010}),
#  frozenset({2802, 2803, 2804}),
#  frozenset({3739, 3740}),
#  frozenset({3760, 3761}),
#  frozenset({4093, 4094}),
#  frozenset({4301, 4302}),
#  frozenset({3443, 3444}),
#  frozenset({3713, 3714}),
#  frozenset({3723, 3724}),
#  frozenset({4303, 4304}),
#  frozenset({2449}),
#  frozenset({3271, 3272, 3273}),
#  frozenset({2397, 2398, 2399}),
#  frozenset({3756, 3757}),
#  frozenset({3064, 3065}),
#  frozenset({3987, 3988}),
#  frozenset({3720}),
#  frozenset({4075, 4076, 4077, 4078}),
#  frozenset({4055, 4056}),
#  frozenset({2623, 2624}),
#  frozenset({3086, 3087, 3088}),
#  frozenset({4089}),
#  frozenset({2984, 2985, 2986}),
#  frozenset({2573, 2574}),
#  frozenset({4322}),
#  frozenset({4357, 4358}),
#  frozenset({2726, 2727}),
#  frozenset({3411, 3412, 3413}),
#  frozenset({3532, 3533}),
#  frozenset({3083, 3084, 3085}),
#  frozenset({3914, 3915, 3916}),
#  frozenset({3552, 3553, 3554}),
#  frozenset({3248, 3249}),
#  frozenset({3164, 3165, 3166}),
#  frozenset({3130, 3131}),
#  frozenset({4125}),
#  frozenset({4232, 4233, 4234}),
#  frozenset({4033, 4034}),
#  frozenset({2712, 2713}),
#  frozenset({3682, 3683, 3684}),
#  frozenset({4079, 4080, 4081}),
#  frozenset({3470, 3471, 3472}),
#  frozenset({3508, 3509}),
#  frozenset({2987, 2988, 2989}),
#  frozenset({3897, 3898}),
#  frozenset({2497, 2498}),
#  frozenset({4029, 4030}),
#  frozenset({4363, 4364}),
#  frozenset({4138, 4139}),
#  frozenset({4444, 4445}),
#  frozenset({3277, 3278, 3279}),
#  frozenset({3224}),
#  frozenset({3596, 3597, 3598}),
#  frozenset({3250}),
#  frozenset({3558, 3560, 3562}),
#  frozenset({3179, 3180}),
#  frozenset({2673}),
#  frozenset({3955}),
#  frozenset({3547, 3548, 3549}),
#  frozenset({4082, 4083}),
#  frozenset({4442, 4443}),
#  frozenset({3515, 3516, 3517}),
#  frozenset({3808, 3809}),
#  frozenset({3621}),
#  frozenset({4220, 4221, 4222}),
#  frozenset({4123}),
#  frozenset({4313, 4314}),
#  frozenset({2587}),
#  frozenset({2602, 2603, 2605}),
#  frozenset({3845, 3846}),
#  frozenset({4126, 4127}),
#  frozenset({4180, 4181}),
#  frozenset({2866, 2867, 2868}),
#  frozenset({3487, 3488}),
#  frozenset({3069}),
#  frozenset({3804, 3805}),
#  frozenset({2556, 2557, 2558}),
#  frozenset({4472, 4473}),
#  frozenset({3014}),
#  frozenset({2643, 2644}),
#  frozenset({2737}),
#  frozenset({2531, 2532}),
#  frozenset({3895, 3896}),
#  frozenset({4045, 4046}),
#  frozenset({2543, 2544}),
#  frozenset({4430, 4431}),
#  frozenset({4466, 4467}),
#  frozenset({4023, 4024}),
#  frozenset({2520, 2521}),
#  frozenset({4015, 4016}),
#  frozenset({3599, 3600, 3601}),
#  frozenset({3364, 3365}),
#  frozenset({3890, 3891}),
#  frozenset({4248}),
#  frozenset({2830, 2831, 2832}),
#  frozenset({3031, 3032}),
#  frozenset({3372, 3373, 3374}),
#  frozenset({3582, 3583, 3584}),
#  frozenset({3089, 3090, 3091}),
#  frozenset({2508, 2509}),
#  frozenset({3181, 3182, 3183}),
#  frozenset({2845, 2846, 2847}),
#  frozenset({3259, 3260, 3261}),
#  frozenset({2633, 2634}),
#  frozenset({3937, 3938}),
#  frozenset({4035, 4036}),
#  frozenset({2952, 2953, 2954}),
#  frozenset({4337, 4338}),
#  frozenset({2604, 2607}),
#  frozenset({3438}),
#  frozenset({3230, 3231}),
#  frozenset({4283, 4284, 4285}),
#  frozenset({4095, 4096, 4097}),
#  frozenset({3054, 3055}),
#  frozenset({3196, 3198, 3199}),
#  frozenset({2904, 2905}),
#  frozenset({3292, 3293}),
#  frozenset({3475, 3476}),
#  frozenset({3745, 3746}),
#  frozenset({4084, 4085, 4086}),
#  frozenset({4440, 4441}),
#  frozenset({2482, 2484}),
#  frozenset({2575, 2576, 2577}),
#  frozenset({4476, 4477}),
#  frozenset({3344, 3345}),
#  frozenset({2473, 2474}),
#  frozenset({3811, 3813}),
#  frozenset({3709, 3710}),
#  frozenset({3479, 3480}),
#  frozenset({4148, 4149}),
#  frozenset({2669, 2670, 2671}),
#  frozenset({2833}),
#  frozenset({3274}),
#  frozenset({3049, 3050}),
#  frozenset({3857, 3858}),
#  frozenset({2423, 2424, 2425}),
#  frozenset({3113, 3114, 3115}),
#  frozenset({2437, 2438, 2439}),
#  frozenset({2808, 2809}),
#  frozenset({2706, 2707, 2708}),
#  frozenset({3056, 3057}),
#  frozenset({4399, 4400}),
#  frozenset({2728, 2729, 2730}),
#  frozenset({3863, 3864}),
#  frozenset({3296, 3297}),
#  frozenset({2548, 2549}),
#  frozenset({3542}),
#  frozenset({2539, 2540}),
#  frozenset({3211, 3212, 3213}),
#  frozenset({3623}),
#  frozenset({3481, 3483}),
#  frozenset({3143, 3144}),
#  frozenset({4027, 4028}),
#  frozenset({3909, 3910}),
#  frozenset({3003, 3004}),
#  frozenset({2621, 2622}),
#  frozenset({4474, 4475}),
#  frozenset({3921, 3922, 3923}),
#  frozenset({2885}),
#  frozenset({2361, 2362, 2363}),
#  frozenset({3749}),
#  frozenset({3855, 3856}),
#  frozenset({3155, 3156, 3157}),
#  frozenset({3316}),
#  frozenset({3619}),
#  frozenset({3733}),
#  frozenset({3754, 3755}),
#  frozenset({3849, 3850, 3851}),
#  frozenset({4202, 4203}),
#  frozenset({2746, 2747, 2748}),
#  frozenset({4329}),
#  frozenset({4053, 4054}),
#  frozenset({3426, 3427, 3428}),
#  frozenset({2370}),
#  frozenset({4341, 4342}),
#  frozenset({3563, 3564}),
#  frozenset({4266, 4267, 4268}),
#  frozenset({2594, 2595, 2596}),
#  frozenset({2321, 2322, 2323}),
#  frozenset({3624}),
#  frozenset({3622}),
#  frozenset({2923, 2924, 2925}),
#  frozenset({3904, 3905}),
#  frozenset({4307, 4308}),
#  frozenset({3451, 3454}),
#  frozenset({4412, 4413}),
#  frozenset({3067}),
#  frozenset({3456, 3457}),
#  frozenset({3694, 3695, 3696}),
#  frozenset({4130, 4131}),
#  frozenset({2475, 2476}),
#  frozenset({3170, 3171, 3172}),
#  frozenset({2432, 2433}),
#  frozenset({3778, 3779}),
#  frozenset({2402, 2403, 2404}),
#  frozenset({3670, 3671, 3672}),
#  frozenset({4229, 4230, 4231}),
#  frozenset({2378, 2379}),
#  frozenset({2662, 2663}),
#  frozenset({2367}),
#  frozenset({3572, 3573}),
#  frozenset({3785, 3786}),
#  frozenset({3867}),
#  frozenset({2666, 2667, 2668}),
#  frozenset({4200, 4201}),
#  frozenset({2941, 2942, 2943}),
#  frozenset({4456, 4457}),
#  frozenset({2717, 2718, 2719}),
#  frozenset({3934}),
#  frozenset({2501, 2502}),
#  frozenset({2392, 2393}),
#  frozenset({4286}),
#  frozenset({2604, 2606, 2607}),
#  frozenset({3979, 3980}),
#  frozenset({3310}),
#  frozenset({3467, 3468, 3469}),
#  frozenset({4134}),
#  frozenset({3847, 3848}),
#  frozenset({2491, 2492}),
#  frozenset({3800, 3801}),
#  frozenset({3841}),
#  frozenset({3439}),
#  frozenset({3027, 3028}),
#  frozenset({3392, 3393, 3394}),
#  frozenset({3602, 3603, 3604}),
#  frozenset({2854, 2855}),
#  frozenset({3747, 3748}),
#  frozenset({3877}),
#  frozenset({2275, 2277, 2278}),
#  frozenset({3752, 3753}),
#  frozenset({4142, 4143}),
#  frozenset({4217, 4218, 4219}),
#  frozenset({2897}),
#  frozenset({4287, 4288, 4289}),
#  frozenset({2929}),
#  frozenset({2874, 2875, 2876}),
#  frozenset({3276}),
#  frozenset({2641, 2642}),
#  frozenset({4327, 4328}),
#  frozenset({4373, 4374, 4375}),
#  frozenset({4368}),
#  frozenset({2303, 2304, 2305}),
#  frozenset({2495, 2496}),
#  frozenset({4462, 4463}),
#  frozenset({3868, 3869, 3870}),
#  frozenset({3315}),
#  frozenset({3312}),
#  frozenset({3245, 3246}),
#  frozenset({3767}),
#  frozenset({3734, 3735}),
#  frozenset({2331, 2332, 2333}),
#  frozenset({4165, 4166}),
#  frozenset({2405, 2406, 2407}),
#  frozenset({4382}),
#  frozenset({4438, 4439}),
#  frozenset({3976, 3977, 3978}),
#  frozenset({2682, 2683, 2684}),
#  frozenset({4277, 4278, 4279}),
#  frozenset({4051, 4052}),
#  frozenset({3968, 3969}),
#  frozenset({4173, 4174}),
#  frozenset({2337, 2338, 2339}),
#  frozenset({2842, 2843, 2844}),
#  frozenset({3302, 3303}),
#  frozenset({2848, 2850}),
#  frozenset({2741, 2742, 2743}),
#  frozenset({2944, 2946}),
#  frozenset({4108, 4109}),
#  frozenset({2699, 2700, 2701}),
#  frozenset({3685, 3686, 3687}),
#  frozenset({3238}),
#  frozenset({3780, 3781}),
#  frozenset({3104, 3105, 3106}),
#  frozenset({3280, 3281, 3282}),
#  frozenset({3187, 3188}),
#  frozenset({2752, 2755}),
#  frozenset({4312}),
#  frozenset({2763, 2764, 2765}),
#  frozenset({3018, 3019, 3020}),
#  frozenset({3816, 3817}),
#  frozenset({3941, 3942}),
#  frozenset({2898, 2899, 2900}),
#  frozenset({3727, 3728}),
#  frozenset({4162}),
#  frozenset({3304}),
#  frozenset({3074}),
#  frozenset({4410, 4411}),
#  frozenset({2306, 2307, 2308}),
#  frozenset({4122}),
#  frozenset({2485, 2486}),
#  frozenset({3568}),
#  frozenset({3559, 3561}),
#  frozenset({3538, 3539}),
#  frozenset({2334, 2335, 2336}),
#  frozenset({3544}),
#  frozenset({2993}),
#  frozenset({3593, 3594, 3595}),
#  frozenset({3629, 3630}),
#  frozenset({3946}),
#  frozenset({3354, 3355, 3356}),
#  frozenset({2827, 2828, 2829}),
#  frozenset({3405, 3406, 3407}),
#  frozenset({2568, 2569}),
#  frozenset({3153, 3154}),
#  frozenset({3703, 3704, 3705}),
#  frozenset({3123, 3124, 3125}),
#  frozenset({4019, 4020}),
#  ...}

# %% [markdown]
# # Métricas

# %%
# Jaccard
def jaccard_char(str1, str2):
    diferenca_char = 0
    # string 2 maior que string 1
    if len(str2) > len(str1):
        inicio = str2.find(str1)
        # teste substring
        if inicio == -1:
            agreement = 0
            return agreement
        else:
            idx_menor = 0
            for idx, _ in enumerate(str2):
                try:
                    # shift na string até encontrar o caractere de inicio
                    if idx < inicio:
                        diferenca_char += 1
                        # contador para shift-reverso
                        idx_menor +=1
                    else:
                        # strings 'alinhadas', diferença char a char
                        if str2[idx] != str1[idx-idx_menor]:
                            diferenca_char += 1
                # acabamos de percorrer str1; computamos a diferença remanescente em relação à str2
                except:
                    dif_reman = len(str2) - idx
                    diferenca_char += dif_reman
                    break
            # computamos o agreement usando jaccard
            agreement = abs(len(str2) - diferenca_char)/len(str2)
            
    # string 1 maior que string 2
    elif len(str1) > len(str2):
        # teste substring
        inicio = str1.find(str2)
        if inicio == -1:
            agreement = 0
            return agreement
        else:
            idx_menor = 0
            for idx, _ in enumerate(str1):
                try:
                    # shift na string até encontrar o caractere de inicio
                    if idx < inicio:
                        diferenca_char += 1
                        # contador para shift-reverso
                        idx_menor +=1
                    else:
                        # strings 'alinhadas', diferença char a char
                        if str1[idx] != str2[idx-idx_menor]:
                            diferenca_char += 1
                # acabamos de percorrer str2; computamos a diferença remanescente em relação à str1
                except:
                    dif_reman = len(str1) - idx
                    diferenca_char += dif_reman
                    break
            # computamos o agreement usando jaccard
            agreement = abs(len(str1) - diferenca_char)/len(str1)
            
    # strings de mesmo tamanho
    else:
        # teste subtring
        inicio = str1.find(str2)
        if inicio == -1:
            agreement = 0
            return agreement
        # str1 e str2 são a mesma string
        elif inicio == 0:
            agreement = 1
        else:
            # strings alinhadas, diferença char a char
            for idx, _ in enumerate(str1):
                if str1[idx] != str2[idx]:
                    diferenca_char += 1
            total_dif = abs(len(str1) - diferenca_char)/len(str1)
            print(f'total_dif caso 3 = {total_dif}')
            agreement = 1 - total_dif
    
    return agreement

# %%
# Cosine similarity
def cos_sim(vec1, vec2):
    dot = np.dot(vec1, vec2)
    norm1 = np.linalg.norm(vec1)
    norm2 = np.linalg.norm(vec2)
    cos = dot/(norm1 * norm2)
    return cos

# %%
# Edit distance
def edit_distance(str1, str2):
    if len(str1) > len(str2):
        str1, str2 = str2, str1

    distances = range(len(str1) + 1)
    for i2, char2 in enumerate(str2):
        distances_ = [i2+1]
        for i1, char1 in enumerate(str1):
            if char1 == char2:
                distances_.append(distances[i1])
            else:
                distances_.append(1 + min((distances[i1], distances[i1 + 1], distances_[-1])))
        distances = distances_
    return distances[-1]

# %% [markdown]
# # Estruturas auxiliares para similaridade cosseno: TFIDF e Word2Vec
#
# _*Similaridade cosseno com Word2Vec não implementada até o momento_

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

corpus = []
for df in dodf_dataframes.values():
    corpus.extend(df['texto'].values)

tfidf_vectorizer = TfidfVectorizer()
tfidf_vectorizer.fit(corpus)

dodf_annotation_tfidfs = {}
for id_dodf, df in dodf_dataframes.items():
    tfidfs = tfidf_vectorizer.transform(df['texto'].values).toarray()
    dodf_annotation_tfidfs[id_dodf] = {index: tfidf for index, tfidf in list(zip(df.index, tfidfs))}

# %% [markdown]
# # Calcula as métricas para cada anotação

# %%
for id_dodf, annotation_groups in dodf_annotation_groups.items():
    df = dodf_dataframes[id_dodf]
    
    if 'edit_distance' not in df:
        df.insert(len(df.columns), 'edit_distance', np.nan)
    if 'jaccard_index' not in df:
        df.insert(len(df.columns), 'jaccard_index', np.nan)
    if 'cos_sim_tfidf' not in df:
        df.insert(len(df.columns), 'cos_sim_tfidf', np.nan)
    if 'cos_sim_word2vec' not in df:
        df.insert(len(df.columns), 'cos_sim_word2vec', np.nan)
    
    for group in annotation_groups:
        pairs = list(itertools.combinations(group, 2))
        group_edit_distances    = []
        group_jaccard_indexes   = []
        group_cos_sims_tfidf    = []
        group_cos_sims_word2vec = []
        
        for anno_index1, anno_index2 in pairs:
            anno1     = df.loc[anno_index1]['texto']
            anno2     = df.loc[anno_index2]['texto']
            tfidf1    = dodf_annotation_tfidfs[id_dodf][anno_index1]
            tfidf2    = dodf_annotation_tfidfs[id_dodf][anno_index2]
            # word2vec1 = get_word2vec(anno1)
            # word2vec2 = get_word2vec(anno2)
            
            group_edit_distances.append(edit_distance(anno1, anno2))
            group_jaccard_indexes.append(jaccard_char(anno1, anno2))
            group_cos_sims_tfidf.append(cos_sim(tfidf1, tfidf2))
            # group_cos_sims_word2vec.append(cos_sim(word2vec1, word2vec2))

        for anno_index in group:
            if group_edit_distances:
                df.loc[anno_index, 'edit_distance']    = np.nanmean(group_edit_distances)
            if group_jaccard_indexes:
                df.loc[anno_index, 'jaccard_index']    = np.nanmean(group_jaccard_indexes)
            if group_cos_sims_tfidf:
                df.loc[anno_index, 'cos_sim_tfidf']    = np.nanmean(group_cos_sims_tfidf)
            # if group_cos_sims_word2vec:
                # df.loc[anno_index, 'cos_sim_word2vec'] = np.nanmean(group_cos_sims_word2vec)
            

dodf_dataframes[672]
# Out:
# /tmp/ipykernel_17277/1194147263.py:6: RuntimeWarning: invalid value encountered in double_scalars
#   cos = dot/(norm1 * norm2)
# /tmp/ipykernel_17277/1194147263.py:6: RuntimeWarning: invalid value encountered in double_scalars
#   cos = dot/(norm1 * norm2)
# /tmp/ipykernel_17277/695528714.py:39: RuntimeWarning: Mean of empty slice
#   df.loc[anno_index, 'cos_sim_tfidf']    = np.nanmean(group_cos_sims_tfidf)
# /tmp/ipykernel_17277/1194147263.py:6: RuntimeWarning: invalid value encountered in double_scalars
#   cos = dot/(norm1 * norm2)
# /tmp/ipykernel_17277/695528714.py:39: RuntimeWarning: Mean of empty slice
#   df.loc[anno_index, 'cos_sim_tfidf']    = np.nanmean(group_cos_sims_tfidf)
#       id_dodf                  tipo_ent  id_ent       anotador_ent  offset  \
# 0         672          EXTRATO_CONTRATO       1  anotador_59684932      23
# 1         672          EXTRATO_CONTRATO       2  anotador_69243565      23
# 2         672          EXTRATO_CONTRATO       3  anotador_72589596      23
# 3         672              processo_gdf       5  anotador_69243565      53
# 4         672              processo_gdf       6  anotador_72589596      53
# ...       ...                       ...     ...                ...     ...
# 2270      672         vigencia_contrato    2375  anotador_59684932  166035
# 2271      672         vigencia_contrato    2376  anotador_69243565  166035
# 2272      672  data_assinatura_contrato    2377  anotador_72589596  166103
# 2273      672  data_assinatura_contrato    2378  anotador_59684932  166103
# 2274      672  data_assinatura_contrato    2379  anotador_69243565  166103
#
#       length                                              texto  \
# 0       1227  EXTRATO DE CONTRATO Processo: 001-000853/2019....
# 1       1227  EXTRATO DE CONTRATO Processo: 001-000853/2019....
# 2       1227  EXTRATO DE CONTRATO Processo: 001-000853/2019....
# 3         15                                    001-000853/2019
# 4         15                                    001-000853/2019
# ...      ...                                                ...
# 2270      46     12 (doze) meses a contar da data de assinatura
# 2271      46     12 (doze) meses a contar da data de assinatura
# 2272      10                                         25/07/2019
# 2273      10                                         25/07/2019
# 2274      10                                         25/07/2019
#
#       edit_distance  jaccard_index  cos_sim_tfidf  cos_sim_word2vec
# 0               0.0            1.0            1.0               NaN
# 1               0.0            1.0            1.0               NaN
# 2               0.0            1.0            1.0               NaN
# 3               0.0            1.0            1.0               NaN
# 4               0.0            1.0            1.0               NaN
# ...             ...            ...            ...               ...
# 2270            0.0            1.0            1.0               NaN
# 2271            0.0            1.0            1.0               NaN
# 2272            0.0            1.0            1.0               NaN
# 2273            0.0            1.0            1.0               NaN
# 2274            0.0            1.0            1.0               NaN
#
# [2275 rows x 11 columns]

# %%
df_with_metrics = pd.DataFrame(columns=dodf_dataframes[id_dodfs[0]].columns)
for df in dodf_dataframes.values():
    df_with_metrics = pd.concat([df_with_metrics, df])

# %%
# Trata valores nan
df_with_metrics.loc[df_with_metrics['edit_distance'].isnull(), 'edit_distance'] = \
    df_with_metrics[df_with_metrics['edit_distance'].isnull()]['length']

df_with_metrics.loc[df_with_metrics['jaccard_index'].isnull(), 'jaccard_index'] = 0
df_with_metrics.loc[df_with_metrics['cos_sim_tfidf'].isnull(), 'cos_sim_tfidf'] = 0
# df_with_metrics.loc[df_with_metrics['cos_sim_w2vec'].isnull(), 'cos_sim_w2vec'] = 0

# %%
csv_with_metrics = "df_with_metrics.csv"
df_with_metrics.to_csv(csv_with_metrics)
df_with_metrics
# Out:
#       id_dodf          tipo_ent id_ent       anotador_ent  offset length  \
# 0         672  EXTRATO_CONTRATO      1  anotador_59684932      23   1227
# 1         672  EXTRATO_CONTRATO      2  anotador_69243565      23   1227
# 2         672  EXTRATO_CONTRATO      3  anotador_72589596      23   1227
# 3         672      processo_gdf      5  anotador_69243565      53     15
# 4         672      processo_gdf      6  anotador_72589596      53     15
# ...       ...               ...    ...                ...     ...    ...
# 27738     638  objeto_licitacao   3737  anotador_37219154  210322    367
# 27739     638   orgao_licitante   3738  anotador_37219154  210631     58
# 27740     638   orgao_licitante   3739  anotador_27589498  210631     58
# 27741     638  nome_responsavel   3740  anotador_37219154  210768     25
# 27742     638  nome_responsavel   3741  anotador_27589498  210769     24
#
#                                                    texto edit_distance  \
# 0      EXTRATO DE CONTRATO Processo: 001-000853/2019....           0.0
# 1      EXTRATO DE CONTRATO Processo: 001-000853/2019....           0.0
# 2      EXTRATO DE CONTRATO Processo: 001-000853/2019....           0.0
# 3                                        001-000853/2019           0.0
# 4                                        001-000853/2019           0.0
# ...                                                  ...           ...
# 27738  Registro de Preços para contratação de empresa...           2.0
# 27739  Secretaria de Estado do Trabalho Distrito Fede...           0.0
# 27740  Secretaria de Estado do Trabalho Distrito Fede...           0.0
# 27741                          JUNILMA OLIVEIRA FERREIRA           1.0
# 27742                           UNILMA OLIVEIRA FERREIRA           1.0
#
#        jaccard_index  cos_sim_tfidf  cos_sim_word2vec
# 0            1.00000       1.000000               NaN
# 1            1.00000       1.000000               NaN
# 2            1.00000       1.000000               NaN
# 3            1.00000       1.000000               NaN
# 4            1.00000       1.000000               NaN
# ...              ...            ...               ...
# 27738        0.99458       1.000000               NaN
# 27739        1.00000       1.000000               NaN
# 27740        1.00000       1.000000               NaN
# 27741        0.96000       0.371556               NaN
# 27742        0.96000       0.371556               NaN
#
# [27743 rows x 11 columns]

# %% [markdown]
# # Valor médio das métricas por tipo de entidade

# %%
# {
#   tipo_ent: {
#       edit_distance: {
#           mean: value,
#           std:  value
#       }
#       jaccard_index: {
#           mean: value,
#           std:  value
#       }
#       cos_sim_tfidf: {
#           mean: value,
#           std:  value
#       }
#       cos_sim_w2vec: {
#           mean: value,
#           std:  value
#       }
#   }
#   ...
# }
metrics_per_type = {}
for entity_type in df_with_metrics['tipo_ent'].unique():
    metrics_per_type[entity_type] = {}
    metrics_per_type[entity_type]['edit_distance'] = {}
    metrics_per_type[entity_type]['jaccard_index'] = {}
    metrics_per_type[entity_type]['cos_sim_tfidf'] = {}
    # metrics_per_type[entity_type]['cos_sim_w2vec'] = {}

    df_entity = df_with_metrics[df_with_metrics['tipo_ent'] == entity_type]
    metrics_per_type[entity_type]['edit_distance']['mean'] = np.mean(df_entity['edit_distance'].values)
    metrics_per_type[entity_type]['edit_distance']['std']  = np.std(df_entity['edit_distance'].values)
    metrics_per_type[entity_type]['jaccard_index']['mean'] = np.mean(df_entity['jaccard_index'].values)
    metrics_per_type[entity_type]['jaccard_index']['std']  = np.std(df_entity['jaccard_index'].values)
    metrics_per_type[entity_type]['cos_sim_tfidf']['mean'] = np.mean(df_entity['cos_sim_tfidf'].values)
    metrics_per_type[entity_type]['cos_sim_tfidf']['std']  = np.std(df_entity['cos_sim_tfidf'].values)
    # metrics_per_type[entity_type]['cos_sim_w2vec']['mean'] = np.mean(df_entity['cos_sim_w2vec'].values)
    # metrics_per_type[entity_type]['cos_sim_w2vec']['std']  = np.std(df_entity['cos_sim_w2vec'].values)

metrics_per_type
# Out:
# {'EXTRATO_CONTRATO': {'edit_distance': {'mean': 147.86977531548175,
#    'std': 485.75061720928346},
#   'jaccard_index': {'mean': 0.8912163084401672, 'std': 0.3041036198430798},
#   'cos_sim_tfidf': {'mean': 0.8970431592485647, 'std': 0.30206541419070465}},
#  'processo_gdf': {'edit_distance': {'mean': 1.2968612191958484,
#    'std': 4.882615658983238},
#   'jaccard_index': {'mean': 0.9369431620358325, 'std': 0.23429849925603094},
#   'cos_sim_tfidf': {'mean': 0.9387333857139728, 'std': 0.2336695737429872}},
#  'numero_contrato': {'edit_distance': {'mean': 1.9859822119102906,
#    'std': 3.255894778340361},
#   'jaccard_index': {'mean': 0.7846096363504178, 'std': 0.3472180101160544},
#   'cos_sim_tfidf': {'mean': 0.7936016601109402, 'std': 0.34502924099619364}},
#  'data_assinatura_contrato': {'edit_distance': {'mean': 1.0546831955922862,
#    'std': 3.103655922920764},
#   'jaccard_index': {'mean': 0.897211787294432, 'std': 0.30025422414294395},
#   'cos_sim_tfidf': {'mean': 0.8969915168284384, 'std': 0.30083157292902235}},
#  'orgao_contratante': {'edit_distance': {'mean': 7.905360764995643,
#    'std': 16.56709609823023},
#   'jaccard_index': {'mean': 0.6881357689558635, 'std': 0.4167303859110989},
#   'cos_sim_tfidf': {'mean': 0.6979539680614578, 'std': 0.4185843549725538}},
#  'entidade_contratada': {'edit_distance': {'mean': 5.804937620804802,
#    'std': 12.610105496356166},
#   'jaccard_index': {'mean': 0.8117855689352546, 'std': 0.3517358145255966},
#   'cos_sim_tfidf': {'mean': 0.8286085347096663, 'std': 0.3478816985518143}},
#  'cnpj_entidade_contratada': {'edit_distance': {'mean': 1.0296296296296295,
#    'std': 3.9321543884276386},
#   'jaccard_index': {'mean': 0.9407137558280934, 'std': 0.22662446873031147},
#   'cos_sim_tfidf': {'mean': 0.9454977845530221, 'std': 0.22464486027811634}},
#  'objeto_contrato': {'edit_distance': {'mean': 37.91937760667283,
#    'std': 125.30903732658713},
#   'jaccard_index': {'mean': 0.8826657013621408, 'std': 0.31274307642573623},
#   'cos_sim_tfidf': {'mean': 0.8884027048705789, 'std': 0.3134860107354674}},
#  'valor_contrato': {'edit_distance': {'mean': 0.8987499999999998,
#    'std': 2.9184087357001807},
#   'jaccard_index': {'mean': 0.9141818314261496, 'std': 0.27642668628786016},
#   'cos_sim_tfidf': {'mean': 0.9154641634220215, 'std': 0.2765884062852549}},
#  'unidade_orcamentaria': {'edit_distance': {'mean': 1.067383512544803,
#    'std': 2.677152227657362},
#   'jaccard_index': {'mean': 0.8736631900735234, 'std': 0.3025036850482216},
#   'cos_sim_tfidf': {'mean': 0.8814999129718812, 'std': 0.30072277111330165}},
#  'programa_trabalho': {'edit_distance': {'mean': 2.883333333333334,
#    'std': 5.95499638099204},
#   'jaccard_index': {'mean': 0.8446254552391714, 'std': 0.32385337297079825},
#   'cos_sim_tfidf': {'mean': 0.8534777168072925, 'std': 0.32487607873080393}},
#  'fonte_recurso': {'edit_distance': {'mean': 3.8922596754057404,
#    'std': 9.787092006257554},
#   'jaccard_index': {'mean': 0.7034091157982348, 'std': 0.426720399140948},
#   'cos_sim_tfidf': {'mean': 0.6878693300041615, 'std': 0.4378746118923653}},
#  'natureza_despesa': {'edit_distance': {'mean': 0.8234929078014183,
#    'std': 1.7318156869115082},
#   'jaccard_index': {'mean': 0.7548398941484048, 'std': 0.3905495157258652},
#   'cos_sim_tfidf': {'mean': 0.763940822648659, 'std': 0.3786874583451984}},
#  'nota_empenho': {'edit_distance': {'mean': 1.1805882352941184,
#    'std': 3.9724742023034145},
#   'jaccard_index': {'mean': 0.8953926636023823, 'std': 0.2895688249098249},
#   'cos_sim_tfidf': {'mean': 0.8986858577498215, 'std': 0.2866906837978986}},
#  'vigencia_contrato': {'edit_distance': {'mean': 17.284506041222333,
#    'std': 43.76731372765109},
#   'jaccard_index': {'mean': 0.7775847663478885, 'std': 0.3655284390605442},
#   'cos_sim_tfidf': {'mean': 0.7905501497939522, 'std': 0.37062824683849127}},
#  'AVISO_LICITACAO': {'edit_distance': {'mean': 28.58915616647579,
#    'std': 169.4732226500112},
#   'jaccard_index': {'mean': 0.9743421670378708, 'std': 0.14216927455523717},
#   'cos_sim_tfidf': {'mean': 0.9777565246804317, 'std': 0.14194862274736436}},
#  'modalidade_licitacao': {'edit_distance': {'mean': 1.5622088353413661,
#    'std': 4.43221596503055},
#   'jaccard_index': {'mean': 0.8950966378142254, 'std': 0.28509627699956214},
#   'cos_sim_tfidf': {'mean': 0.8933777733094039, 'std': 0.2872172294755345}},
#  'numero_licitacao': {'edit_distance': {'mean': 2.6195695307108324,
#    'std': 51.01720586554318},
#   'jaccard_index': {'mean': 0.8967248498951398, 'std': 0.2514939760845735},
#   'cos_sim_tfidf': {'mean': 0.8961998907389157, 'std': 0.2516796461138646}},
#  'objeto_licitacao': {'edit_distance': {'mean': 30.682439537329103,
#    'std': 90.33542786780637},
#   'jaccard_index': {'mean': 0.8688368256925386, 'std': 0.3073232279924792},
#   'cos_sim_tfidf': {'mean': 0.8913969005226468, 'std': 0.3022272268529589}},
#  'tipo_objeto': {'edit_distance': {'mean': 4.0077892325315005,
#    'std': 6.184483855781651},
#   'jaccard_index': {'mean': 0.6857915803631838, 'std': 0.4528153910176842},
#   'cos_sim_tfidf': {'mean': 0.6831932844037021, 'std': 0.4540439049055529}},
#  'orgao_licitante': {'edit_distance': {'mean': 6.243084779131295,
#    'std': 17.285777896327296},
#   'jaccard_index': {'mean': 0.7478087306440349, 'std': 0.41695367742270384},
#   'cos_sim_tfidf': {'mean': 0.7491299347520595, 'std': 0.41588456779183847}},
#  'valor_estimado_contratacao': {'edit_distance': {'mean': 0.41607142857142854,
#    'std': 1.9682246761613285},
#   'jaccard_index': {'mean': 0.9584706959706959, 'std': 0.19456183154340245},
#   'cos_sim_tfidf': {'mean': 0.9607142857142857, 'std': 0.1942738966994164}},
#  'data_abertura_licitacao': {'edit_distance': {'mean': 0.8443271767810027,
#    'std': 3.193750206018564},
#   'jaccard_index': {'mean': 0.9314811374803044, 'std': 0.24763651282833818},
#   'cos_sim_tfidf': {'mean': 0.9320030591094837, 'std': 0.2464142558867413}},
#  'data_escrito': {'edit_distance': {'mean': 1.4195833333333334,
#    'std': 4.269061760908632},
#   'jaccard_index': {'mean': 0.8945231331168831, 'std': 0.3005227822167634},
#   'cos_sim_tfidf': {'mean': 0.8967347717600881, 'std': 0.29996979400825846}},
#  'sistema_compras': {'edit_distance': {'mean': 2.020703703703704,
#    'std': 7.465517421384652},
#   'jaccard_index': {'mean': 0.9253151779803592, 'std': 0.25586568686359734},
#   'cos_sim_tfidf': {'mean': 0.9264016796979204, 'std': 0.25444296149471096}},
#  'codigo_licitacao_sistema_compras': {'edit_distance': {'mean': 0.48866027589431854,
#    'std': 1.9567334228587474},
#   'jaccard_index': {'mean': 0.9416381490849575, 'std': 0.19373092660992913},
#   'cos_sim_tfidf': {'mean': 0.9425508002741376, 'std': 0.1930126566024192}},
#  'nome_responsavel': {'edit_distance': {'mean': 1.1087066779374468,
#    'std': 4.698563284372661},
#   'jaccard_index': {'mean': 0.9505287059855179, 'std': 0.20090081456729114},
#   'cos_sim_tfidf': {'mean': 0.9497980788252106, 'std': 0.20110840812729577}},
#  'AVISO_SUSPENSAO_LICITACAO': {'edit_distance': {'mean': 27.261904761904763,
#    'std': 203.9256469920688},
#   'jaccard_index': {'mean': 0.9751856705985147, 'std': 0.15243417433613485},
#   'cos_sim_tfidf': {'mean': 0.9759574682918443, 'std': 0.15242624698909563}},
#  'EXTRATO_ADITAMENTO_CONTRATUAL': {'edit_distance': {'mean': 65.15079626578803,
#    'std': 292.833193093768},
#   'jaccard_index': {'mean': 0.9333281867540866, 'std': 0.2419133495942704},
#   'cos_sim_tfidf': {'mean': 0.9413650343855714, 'std': 0.23294120523077017}},
#  'numero_termo_aditivo': {'edit_distance': {'mean': 1.4357749469214436,
#    'std': 4.893445041190158},
#   'jaccard_index': {'mean': 0.9269202196094292, 'std': 0.24852429108735757},
#   'cos_sim_tfidf': {'mean': 0.9290422546280203, 'std': 0.246320352388885}},
#  'objeto_aditamento_contratual': {'edit_distance': {'mean': 97.05242024202417,
#    'std': 265.9196357018888},
#   'jaccard_index': {'mean': 0.7772386060805474, 'std': 0.4115406713671114},
#   'cos_sim_tfidf': {'mean': 0.7793756104225492, 'std': 0.4120705969379347}},
#  'AVISO_ANUL_REV_LICITACAO': {'edit_distance': {'mean': 33.93333333333333,
#    'std': 165.47405301805546},
#   'jaccard_index': {'mean': 0.9628097809188425, 'std': 0.1790584966929601},
#   'cos_sim_tfidf': {'mean': 0.965493622740635, 'std': 0.17931330578238586}},
#  'identificacao_ocorrencia': {'edit_distance': {'mean': 2.3636363636363638,
#    'std': 4.625622998436085},
#   'jaccard_index': {'mean': 0.8167388167388168, 'std': 0.3313943216204571},
#   'cos_sim_tfidf': {'mean': 0.821803116131977, 'std': 0.3244447103727159}},
#  'decisao_tcdf': {'edit_distance': {'mean': 23.0, 'std': 36.670175270728734},
#   'jaccard_index': {'mean': 0.23905817174515237, 'std': 0.25754814437680523},
#   'cos_sim_tfidf': {'mean': 0.39709358569246467, 'std': 0.4187073190824244}},
#  'cnpj_orgao_contratante': {'edit_distance': {'mean': 2.27887323943662,
#    'std': 7.113682818164789},
#   'jaccard_index': {'mean': 0.8929577464788733, 'std': 0.3036509966920984},
#   'cos_sim_tfidf': {'mean': 0.8929577464788733, 'std': 0.3036509966920984}},
#  'codigo_siggo': {'edit_distance': {'mean': 0.7385342789598109,
#    'std': 1.6712479998128746},
#   'jaccard_index': {'mean': 0.780614657210402, 'std': 0.38082809750359536},
#   'cos_sim_tfidf': {'mean': 0.780614657210402, 'std': 0.38082809750359536}},
#  'EXTRATO_CONVENIO': {'edit_distance': {'mean': 646.6666666666666,
#    'std': 590.5995070923932},
#   'jaccard_index': {'mean': 0.3330767256864255, 'std': 0.4710417276199714},
#   'cos_sim_tfidf': {'mean': 0.3333333333333333, 'std': 0.4714045207910317}},
#  'entidade_convenente': {'edit_distance': {'mean': 20.8,
#    'std': 17.97665152357357},
#   'jaccard_index': {'mean': 0.2, 'std': 0.4000000000000001},
#   'cos_sim_tfidf': {'mean': 0.2, 'std': 0.4000000000000001}},
#  'cnpj_entidade_convenente': {'edit_distance': {'mean': 13.5,
#    'std': 7.794228634059948},
#   'jaccard_index': {'mean': 0.25, 'std': 0.4330127018922193},
#   'cos_sim_tfidf': {'mean': 0.25000000000000006, 'std': 0.4330127018922194}},
#  'orgao_concedente': {'edit_distance': {'mean': 34.285714285714285,
#    'std': 11.119022127022882},
#   'jaccard_index': {'mean': 0.0, 'std': 0.0},
#   'cos_sim_tfidf': {'mean': 0.0, 'std': 0.0}},
#  'cnpj_orgao_concedente': {'edit_distance': {'mean': 18.0, 'std': 0.0},
#   'jaccard_index': {'mean': 0.0, 'std': 0.0},
#   'cos_sim_tfidf': {'mean': 0.0, 'std': 0.0}},
#  'objeto_convenio': {'edit_distance': {'mean': 110.72727272727273,
#    'std': 179.1749226107325},
#   'jaccard_index': {'mean': 0.5430568346452334, 'std': 0.49574627907812474},
#   'cos_sim_tfidf': {'mean': 0.5454545454545454, 'std': 0.4979295977319692}},
#  'vigencia_convenio': {'edit_distance': {'mean': 25.444444444444443,
#    'std': 23.01743837041391},
#   'jaccard_index': {'mean': 0.4188034188034188, 'std': 0.4698134411046774},
#   'cos_sim_tfidf': {'mean': 0.4409699195007164, 'std': 0.4930469045726285}},
#  'valor_convenio': {'edit_distance': {'mean': 4.0, 'std': 5.656854249492381},
#   'jaccard_index': {'mean': 0.6666666666666666, 'std': 0.4714045207910317},
#   'cos_sim_tfidf': {'mean': 0.6666666666666666, 'std': 0.4714045207910317}},
#  'data_assinatura_convenio': {'edit_distance': {'mean': 9.875,
#    'std': 10.647035972513665},
#   'jaccard_index': {'mean': 0.5, 'std': 0.5},
#   'cos_sim_tfidf': {'mean': 0.5, 'std': 0.5}},
#  'numero_convenio': {'edit_distance': {'mean': 6.777777777777778,
#    'std': 4.939135726865082},
#   'jaccard_index': {'mean': 0.2222222222222222, 'std': 0.41573970964154905},
#   'cos_sim_tfidf': {'mean': 0.2222222222222222, 'std': 0.41573970964154905}}}

# %% [markdown]
# # Krinppendorff alpha

# %%
# Codificando labels de tipo de entidade para usar na matriz de entrada
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
label_encoder.fit(df_with_metrics['tipo_ent'].values)
label_encoder.classes_
# Out:
# array(['AVISO_ANUL_REV_LICITACAO', 'AVISO_LICITACAO',
#        'AVISO_SUSPENSAO_LICITACAO', 'EXTRATO_ADITAMENTO_CONTRATUAL',
#        'EXTRATO_CONTRATO', 'EXTRATO_CONVENIO', 'cnpj_entidade_contratada',
#        'cnpj_entidade_convenente', 'cnpj_orgao_concedente',
#        'cnpj_orgao_contratante', 'codigo_licitacao_sistema_compras',
#        'codigo_siggo', 'data_abertura_licitacao',
#        'data_assinatura_contrato', 'data_assinatura_convenio',
#        'data_escrito', 'decisao_tcdf', 'entidade_contratada',
#        'entidade_convenente', 'fonte_recurso', 'identificacao_ocorrencia',
#        'modalidade_licitacao', 'natureza_despesa', 'nome_responsavel',
#        'nota_empenho', 'numero_contrato', 'numero_convenio',
#        'numero_licitacao', 'numero_termo_aditivo',
#        'objeto_aditamento_contratual', 'objeto_contrato',
#        'objeto_convenio', 'objeto_licitacao', 'orgao_concedente',
#        'orgao_contratante', 'orgao_licitante', 'processo_gdf',
#        'programa_trabalho', 'sistema_compras', 'tipo_objeto',
#        'unidade_orcamentaria', 'valor_contrato', 'valor_convenio',
#        'valor_estimado_contratacao', 'vigencia_contrato',
#        'vigencia_convenio'], dtype=object)

# %%
# {
#   annotation_group: {
#       anotador_ent: label,
#       anotador_ent: label,
#       ...
#   }
#   ...
# }
dict_krippendorff = {}
for annotation_groups in dodf_annotation_groups.values():
    for group in annotation_groups:
        dict_krippendorff[group] = {}
        for anno_index in group:
            annotator = df_with_metrics.loc[anno_index]['anotador_ent']
            label = label_encoder.transform([df_with_metrics.loc[anno_index]['tipo_ent']])
            dict_krippendorff[group][annotator] = label[0]

dict_krippendorff
# Out:
# {frozenset({1217, 1218, 1219}): {'anotador_135115': 27,
#   'anotador_26827896': 27,
#   'anotador_59821738': 27},
#  frozenset({1535, 1536, 1537}): {'anotador_26827896': 43,
#   'anotador_59821738': 43,
#   'anotador_135115': 43},
#  frozenset({1930, 1931, 1932}): {'anotador_59821738': 38,
#   'anotador_26827896': 38,
#   'anotador_135115': 38},
#  frozenset({1997, 1998, 1999}): {'anotador_59821738': 10,
#   'anotador_26827896': 10,
#   'anotador_135115': 10},
#  frozenset({1102, 1103, 1104}): {'anotador_69243565': 4,
#   'anotador_72589596': 25,
#   'anotador_59684932': 25},
#  frozenset({413, 414}): {'anotador_46084830': 25, 'anotador_37204582': 25},
#  frozenset({552, 553, 554}): {'anotador_135115': 36,
#   'anotador_59821738': 36,
#   'anotador_26827896': 36},
#  frozenset({277, 278}): {'anotador_26827896': 1, 'anotador_59821738': 1},
#  frozenset({999, 1000}): {'anotador_26827896': 36, 'anotador_135115': 36},
#  frozenset({1069}): {'anotador_26827896': 35},
#  frozenset({517, 518}): {'anotador_37204582': 34, 'anotador_46084830': 34},
#  frozenset({926}): {'anotador_72589596': 34},
#  frozenset({100, 101, 102}): {'anotador_135115': 43,
#   'anotador_59821738': 43,
#   'anotador_26827896': 43},
#  frozenset({1904, 1905, 1906}): {'anotador_59821738': 23,
#   'anotador_26827896': 23,
#   'anotador_135115': 23},
#  frozenset({628, 629}): {'anotador_59821738': 35, 'anotador_26827896': 35},
#  frozenset({1988}): {'anotador_135115': 19},
#  frozenset({784, 785, 786}): {'anotador_135115': 39,
#   'anotador_59821738': 39,
#   'anotador_26827896': 39},
#  frozenset({147, 148, 149}): {'anotador_135115': 10,
#   'anotador_59821738': 10,
#   'anotador_26827896': 10},
#  frozenset({238, 240}): {'anotador_26827896': 32, 'anotador_59821738': 32},
#  frozenset({940, 941}): {'anotador_59684932': 25, 'anotador_72589596': 25},
#  frozenset({2266, 2267, 2268}): {'anotador_72589596': 19,
#   'anotador_59684932': 19,
#   'anotador_69243565': 19},
#  frozenset({303, 304}): {'anotador_37204582': 28, 'anotador_46084830': 28},
#  frozenset({1498, 1500}): {'anotador_26827896': 32, 'anotador_59821738': 32},
#  frozenset({827}): {'anotador_46084830': 34},
#  frozenset({1907, 1908, 1909}): {'anotador_59821738': 1,
#   'anotador_26827896': 1,
#   'anotador_135115': 1},
#  frozenset({73, 74}): {'anotador_59821738': 38, 'anotador_26827896': 38},
#  frozenset({1789, 1790, 1791}): {'anotador_69243565': 24,
#   'anotador_72589596': 24,
#   'anotador_59684932': 24},
#  frozenset({1697, 1698, 1699}): {'anotador_135115': 35,
#   'anotador_26827896': 35,
#   'anotador_59821738': 38},
#  frozenset({561, 562, 563}): {'anotador_135115': 43,
#   'anotador_59821738': 43,
#   'anotador_26827896': 43},
#  frozenset({30, 31, 32}): {'anotador_72589596': 37,
#   'anotador_59684932': 37,
#   'anotador_69243565': 37},
#  frozenset({1802, 1803}): {'anotador_37204582': 15, 'anotador_46084830': 15},
#  frozenset({2095, 2096, 2097}): {'anotador_69243565': 37,
#   'anotador_59684932': 37,
#   'anotador_72589596': 37},
#  frozenset({1971, 1972, 1973}): {'anotador_59821738': 1,
#   'anotador_26827896': 1,
#   'anotador_135115': 1},
#  frozenset({1211}): {'anotador_72589596': 34},
#  frozenset({848, 849, 850}): {'anotador_59684932': 17,
#   'anotador_69243565': 17,
#   'anotador_72589596': 17},
#  frozenset({1675, 1676}): {'anotador_26827896': 12, 'anotador_59821738': 12},
#  frozenset({579, 580, 581}): {'anotador_59821738': 1,
#   'anotador_26827896': 1,
#   'anotador_135115': 1},
#  frozenset({1655, 1656, 1657}): {'anotador_135115': 23,
#   'anotador_59821738': 23,
#   'anotador_26827896': 23},
#  frozenset({1362, 1363}): {'anotador_26827896': 39, 'anotador_59821738': 39},
#  frozenset({2155, 2156}): {'anotador_37204582': 3, 'anotador_46084830': 3},
#  frozenset({857, 858, 859}): {'anotador_59684932': 30,
#   'anotador_69243565': 30,
#   'anotador_72589596': 30},
#  frozenset({1481, 1482}): {'anotador_37219154': 35, 'anotador_27589498': 35},
#  frozenset({446, 447}): {'anotador_59821738': 35, 'anotador_26827896': 35},
#  frozenset({1811, 1812}): {'anotador_59821738': 21, 'anotador_26827896': 21},
#  frozenset({663, 664, 665}): {'anotador_59821738': 12,
#   'anotador_26827896': 12,
#   'anotador_135115': 12},
#  frozenset({987, 988, 989}): {'anotador_26827896': 10,
#   'anotador_59821738': 10,
#   'anotador_135115': 10},
#  frozenset({1229, 1230}): {'anotador_26827896': 35, 'anotador_59821738': 35},
#  frozenset({2015, 2018, 2020}): {'anotador_59821738': 32,
#   'anotador_26827896': 32,
#   'anotador_135115': 32},
#  frozenset({823}): {'anotador_37204582': 36},
#  frozenset({2029, 2030, 2031}): {'anotador_135115': 10,
#   'anotador_59821738': 10,
#   'anotador_26827896': 10},
#  frozenset({364, 365}): {'anotador_26827896': 21, 'anotador_59821738': 21},
#  frozenset({1126, 1127, 1128}): {'anotador_59684932': 37,
#   'anotador_69243565': 37,
#   'anotador_72589596': 22},
#  frozenset({811, 812}): {'anotador_37204582': 34, 'anotador_46084830': 34},
#  frozenset({1135, 1136, 1137}): {'anotador_72589596': 44,
#   'anotador_59684932': 44,
#   'anotador_69243565': 44},
#  frozenset({1002}): {'anotador_26827896': 35},
#  frozenset({1369, 1370, 1371}): {'anotador_26827896': 12,
#   'anotador_135115': 12,
#   'anotador_59821738': 12},
#  frozenset({188, 189}): {'anotador_26827896': 35, 'anotador_59821738': 35},
#  frozenset({736, 737}): {'anotador_37204582': 25, 'anotador_46084830': 25},
#  frozenset({1250, 1251, 1252}): {'anotador_26827896': 27,
#   'anotador_135115': 27,
#   'anotador_59821738': 27},
#  frozenset({2175, 2176}): {'anotador_46084830': 25, 'anotador_37204582': 25},
#  frozenset({2204, 2205, 2206}): {'anotador_37204582': 15,
#   'anotador_72589596': 13,
#   'anotador_46084830': 15},
#  frozenset({1891}): {'anotador_135115': 19},
#  frozenset({1774, 1775, 1776}): {'anotador_59684932': 41,
#   'anotador_69243565': 41,
#   'anotador_72589596': 41},
#  frozenset({835}): {'anotador_46084830': 29},
#  frozenset({724, 725}): {'anotador_26827896': 43, 'anotador_59821738': 43},
#  frozenset({1489, 1490}): {'anotador_26827896': 1, 'anotador_59821738': 27},
#  frozenset({1132, 1133, 1134}): {'anotador_59684932': 19,
#   'anotador_69243565': 19,
#   'anotador_72589596': 19},
#  frozenset({1030, 1031}): {'anotador_59821738': 38, 'anotador_26827896': 38},
#  frozenset({635}): {'anotador_26827896': 38},
#  frozenset({805, 806}): {'anotador_37204582': 25, 'anotador_46084830': 25},
#  frozenset({1319}): {'anotador_59821738': 43},
#  frozenset({267, 268}): {'anotador_26827896': 36, 'anotador_59821738': 36},
#  frozenset({1428}): {'anotador_26827896': 32},
#  frozenset({1741, 1742, 1743}): {'anotador_26827896': 43,
#   'anotador_135115': 43,
#   'anotador_59821738': 43},
#  frozenset({2167, 2168}): {'anotador_46084830': 29, 'anotador_37204582': 29},
#  frozenset({2220, 2221, 2222}): {'anotador_135115': 27,
#   'anotador_59821738': 27,
#   'anotador_26827896': 27},
#  frozenset({1886, 1888, 1890}): {'anotador_26827896': 32,
#   'anotador_135115': 32,
#   'anotador_59821738': 32},
#  frozenset({683}): {'anotador_27589498': 32},
#  frozenset({1080, 1081}): {'anotador_72589596': 4, 'anotador_59684932': 4},
#  frozenset({2104, 2105, 2106}): {'anotador_72589596': 13,
#   'anotador_69243565': 13,
#   'anotador_59684932': 13},
#  frozenset({125, 126}): {'anotador_26827896': 10, 'anotador_135115': 10},
#  frozenset({283, 284}): {'anotador_26827896': 10, 'anotador_59821738': 10},
#  frozenset({1945, 1946, 1947}): {'anotador_59821738': 27,
#   'anotador_26827896': 27,
#   'anotador_135115': 27},
#  frozenset({1585}): {'anotador_37204582': 34},
#  frozenset({1844, 1845}): {'anotador_59821738': 21, 'anotador_26827896': 21},
#  frozenset({1286}): {'anotador_72589596': 13},
#  frozenset({235, 236}): {'anotador_59821738': 10, 'anotador_26827896': 10},
#  frozenset({1052, 1053}): {'anotador_59821738': 10, 'anotador_26827896': 10},
#  frozenset({457, 458, 459}): {'anotador_135115': 23,
#   'anotador_59821738': 23,
#   'anotador_26827896': 23},
#  frozenset({1628}): {'anotador_46084830': 25},
#  frozenset({564, 565, 566}): {'anotador_135115': 12,
#   'anotador_59821738': 12,
#   'anotador_26827896': 12},
#  frozenset({1129, 1130, 1131}): {'anotador_69243565': 22,
#   'anotador_72589596': 22,
#   'anotador_59684932': 22},
#  frozenset({1755, 1756, 1757}): {'anotador_69243565': 25,
#   'anotador_72589596': 25,
#   'anotador_59684932': 25},
#  frozenset({1463, 1464}): {'anotador_59821738': 39, 'anotador_26827896': 39},
#  frozenset({1710}): {'anotador_59821738': 43},
#  frozenset({730, 731}): {'anotador_26827896': 23, 'anotador_59821738': 23},
#  frozenset({1315, 1317}): {'anotador_26827896': 32, 'anotador_59821738': 32},
#  frozenset({490, 491, 492}): {'anotador_135115': 23,
#   'anotador_59821738': 23,
#   'anotador_26827896': 23},
#  frozenset({2235}): {'anotador_26827896': 35},
#  frozenset({1372, 1373}): {'anotador_26827896': 38, 'anotador_59821738': 38},
#  frozenset({142, 143}): {'anotador_26827896': 21, 'anotador_59821738': 21},
#  frozenset({1066, 1068}): {'anotador_59821738': 32, 'anotador_26827896': 32},
#  frozenset({590, 593, 595}): {'anotador_59821738': 32,
#   'anotador_26827896': 32,
#   'anotador_135115': 32},
#  frozenset({1232}): {'anotador_26827896': 35},
#  frozenset({1082, 1083}): {'anotador_72589596': 36, 'anotador_59684932': 36},
#  frozenset({499, 500}): {'anotador_46084830': 36, 'anotador_37204582': 36},
#  frozenset({2136, 2137, 2138}): {'anotador_72589596': 37,
#   'anotador_69243565': 37,
#   'anotador_59684932': 37},
#  frozenset({751, 752}): {'anotador_27589498': 36, 'anotador_37219154': 36},
#  frozenset({539, 540}): {'anotador_37204582': 29, 'anotador_46084830': 29},
#  frozenset({760, 761}): {'anotador_37204582': 28, 'anotador_46084830': 28},
#  frozenset({1333, 1334}): {'anotador_37219154': 35, 'anotador_27589498': 35},
#  frozenset({62, 63}): {'anotador_59821738': 35, 'anotador_26827896': 35},
#  frozenset({2036, 2037, 2038}): {'anotador_135115': 1,
#   'anotador_26827896': 1,
#   'anotador_59821738': 1},
#  frozenset({1284}): {'anotador_72589596': 34},
#  frozenset({1491, 1492}): {'anotador_26827896': 21, 'anotador_59821738': 21},
#  frozenset({2201, 2203}): {'anotador_37204582': 29, 'anotador_46084830': 29},
#  frozenset({1413, 1414, 1415}): {'anotador_69243565': 24,
#   'anotador_72589596': 24,
#   'anotador_59684932': 24},
#  frozenset({1874, 1875, 1876}): {'anotador_59821738': 1,
#   'anotador_26827896': 1,
#   'anotador_135115': 1},
#  frozenset({253, 254}): {'anotador_26827896': 1, 'anotador_59821738': 1},
#  frozenset({2064, 2065, 2066}): {'anotador_135115': 23,
#   'anotador_59821738': 23,
#   'anotador_26827896': 23},
#  frozenset({631}): {'anotador_59821738': 43},
#  frozenset({1323, 1324}): {'anotador_26827896': 23, 'anotador_59821738': 23},
#  frozenset({384, 385}): {'anotador_26827896': 38, 'anotador_59821738': 38},
#  frozenset({1580}): {'anotador_37204582': 3},
#  frozenset({515}): {'anotador_46084830': 29},
#  frozenset({918}): {'anotador_37204582': 29},
#  frozenset({749, 750}): {'anotador_37219154': 27, 'anotador_27589498': 27},
#  frozenset({403}): {'anotador_26827896': 35},
#  frozenset({1424, 1425}): {'anotador_135115': 27, 'anotador_26827896': 27},
#  frozenset({1600, 1601}): {'anotador_37219154': 23, 'anotador_27589498': 23},
#  frozenset({144, 145, 146}): {'anotador_135115': 27,
#   'anotador_26827896': 27,
#   'anotador_59821738': 27},
#  frozenset({448, 449, 450}): {'anotador_135115': 36,
#   'anotador_59821738': 36,
#   'anotador_26827896': 36},
#  frozenset({1927, 1928, 1929}): {'anotador_26827896': 12,
#   'anotador_135115': 12,
#   'anotador_59821738': 12},
#  frozenset({1739, 1740}): {'anotador_26827896': 35, 'anotador_59821738': 35},
#  frozenset({1708, 1709}): {'anotador_26827896': 36, 'anotador_59821738': 36},
#  frozenset({2165, 2166}): {'anotador_37204582': 15, 'anotador_46084830': 15},
#  frozenset({325, 326, 327}): {'anotador_69243565': 34,
#   'anotador_72589596': 34,
#   'anotador_59684932': 34},
#  frozenset({452, 453, 454}): {'anotador_26827896': 12,
#   'anotador_135115': 12,
#   'anotador_59821738': 12},
#  frozenset({241, 242}): {'anotador_59821738': 35, 'anotador_26827896': 35},
#  frozenset({1287, 1288}): {'anotador_37204582': 3, 'anotador_46084830': 3},
#  frozenset({2139, 2140, 2141}): {'anotador_72589596': 22,
#   'anotador_69243565': 22,
#   'anotador_59684932': 22},
#  frozenset({1450, 1451, 1452}): {'anotador_26827896': 10,
#   'anotador_135115': 10,
#   'anotador_59821738': 10},
#  frozenset({1964, 1965, 1966}): {'anotador_59821738': 10,
#   'anotador_26827896': 10,
#   'anotador_135115': 10},
#  frozenset({1105, 1106, 1107}): {'anotador_69243565': 36,
#   'anotador_72589596': 36,
#   'anotador_59684932': 36},
#  frozenset({954, 955}): {'anotador_72589596': 34, 'anotador_59684932': 34},
#  frozenset({929}): {'anotador_72589596': 25},
#  frozenset({2021}): {'anotador_135115': 19},
#  frozenset({1089, 1090}): {'anotador_59684932': 17, 'anotador_72589596': 17},
#  frozenset({1583}): {'anotador_37204582': 36},
#  frozenset({1680, 1681}): {'anotador_26827896': 38, 'anotador_59821738': 38},
#  frozenset({1958, 1959, 1960}): {'anotador_135115': 12,
#   'anotador_59821738': 12,
#   'anotador_26827896': 12},
#  frozenset({207, 208}): {'anotador_26827896': 21, 'anotador_59821738': 21},
#  frozenset({2169}): {'anotador_46084830': 25},
#  frozenset({2108, 2109, 2110}): {'anotador_59684932': 4,
#   'anotador_72589596': 4,
#   'anotador_69243565': 4},
#  frozenset({1716, 1717, 1718}): {'anotador_26827896': 23,
#   'anotador_135115': 23,
#   'anotador_59821738': 23},
#  frozenset({0, 1, 2}): {'anotador_59684932': 4,
#   'anotador_69243565': 4,
#   'anotador_72589596': 4},
#  frozenset({832}): {'anotador_46084830': 28},
#  frozenset({511, 512}): {'anotador_46084830': 25, 'anotador_37204582': 25},
#  frozenset({636, 637, 638}): {'anotador_135115': 38,
#   'anotador_59821738': 38,
#   'anotador_26827896': 38},
#  frozenset({1325, 1326}): {'anotador_27589498': 2, 'anotador_37219154': 2},
#  frozenset({1003, 1005}): {'anotador_135115': 32, 'anotador_26827896': 32},
#  frozenset({1138, 1139, 1140}): {'anotador_69243565': 13,
#   'anotador_72589596': 13,
#   'anotador_59684932': 13},
#  frozenset({829}): {'anotador_46084830': 34},
#  frozenset({905, 906}): {'anotador_46084830': 28, 'anotador_37204582': 28},
#  frozenset({574}): {'anotador_26827896': 38},
#  frozenset({444, 445}): {'anotador_59821738': 39, 'anotador_26827896': 39},
#  frozenset({361, 362, 363}): {'anotador_135115': 1,
#   'anotador_59821738': 1,
#   'anotador_26827896': 1},
#  frozenset({2248, 2249, 2250}): {'anotador_72589596': 34,
#   'anotador_59684932': 34,
#   'anotador_69243565': 34},
#  frozenset({9, 10}): {'anotador_69243565': 13, 'anotador_72589596': 13},
#  frozenset({973, 974, 976}): {'anotador_59821738': 39,
#   'anotador_135115': 39,
#   'anotador_26827896': 39},
#  frozenset({1596, 1597}): {'anotador_27589498': 32, 'anotador_37219154': 32},
#  frozenset({129}): {'anotador_135115': 39},
#  frozenset({78, 79, 80}): {'anotador_59821738': 23,
#   'anotador_135115': 23,
#   'anotador_26827896': 23},
#  frozenset({523, 524}): {'anotador_37204582': 25, 'anotador_46084830': 25},
#  frozenset({742, 743}): {'anotador_37204582': 29, 'anotador_46084830': 29},
#  frozenset({1015, 1017, 1018}): {'anotador_26827896': 32,
#   'anotador_135115': 32,
#   'anotador_59821738': 32},
#  frozenset({81, 82, 83}): {'anotador_26827896': 1,
#   'anotador_135115': 1,
#   'anotador_59821738': 1},
#  frozenset({432, 433, 434, 435, 436, 437, 438, 439}): {'anotador_135115': 35,
#   'anotador_26827896': 35,
#   'anotador_59821738': 10},
#  frozenset({1295}): {'anotador_37204582': 15},
#  frozenset({2098, 2099, 2100}): {'anotador_72589596': 22,
#   'anotador_69243565': 22,
#   'anotador_59684932': 22},
#  frozenset({196, 197, 198}): {'anotador_59821738': 12,
#   'anotador_135115': 12,
#   'anotador_26827896': 12},
#  frozenset({455, 456}): {'anotador_26827896': 38, 'anotador_59821738': 38},
#  frozenset({33, 34, 35}): {'anotador_72589596': 19,
#   'anotador_59684932': 19,
#   'anotador_69243565': 19},
#  frozenset({43, 44}): {'anotador_69243565': 44, 'anotador_72589596': 44},
#  frozenset({1501, 1502}): {'anotador_26827896': 35, 'anotador_59821738': 35},
#  frozenset({678, 679}): {'anotador_27589498': 21, 'anotador_37219154': 21},
#  frozenset({654, 655, 657}): {'anotador_59821738': 39,
#   'anotador_135115': 39,
#   'anotador_26827896': 39},
#  frozenset({48, 49}): {'anotador_59821738': 21, 'anotador_26827896': 21},
#  frozenset({587, 588, 589}): {'anotador_135115': 36,
#   'anotador_59821738': 36,
#   'anotador_26827896': 36},
#  frozenset({1846, 1847, 1848}): {'anotador_135115': 27,
#   'anotador_59821738': 27,
#   'anotador_26827896': 27},
#  frozenset({1792, 1793, 1794}): {'anotador_69243565': 44,
#   'anotador_72589596': 44,
#   'anotador_59684932': 44},
#  frozenset({938, 939}): {'anotador_59684932': 36, 'anotador_72589596': 36},
#  frozenset({1650, 1651, 1652}): {'anotador_26827896': 43,
#   'anotador_135115': 43,
#   'anotador_59821738': 43},
#  frozenset({708, 709}): {'anotador_26827896': 1, 'anotador_59821738': 1},
#  frozenset({1337, 1338}): {'anotador_37219154': 27, 'anotador_27589498': 27},
#  frozenset({1604, 1605}): {'anotador_37204582': 28, 'anotador_46084830': 28},
#  frozenset({994}): {'anotador_26827896': 35},
#  frozenset({1277}): {'anotador_135115': 38},
#  frozenset({674, 675}): {'anotador_27589498': 20, 'anotador_37219154': 20},
#  frozenset({1653, 1654}): {'anotador_26827896': 38, 'anotador_59821738': 38},
#  frozenset({2127, 2128, 2129}): {'anotador_72589596': 41,
#   'anotador_69243565': 41,
#   'anotador_59684932': 41},
#  frozenset({1761, 1762, 1763}): {'anotador_69243565': 34,
#   'anotador_72589596': 34,
#   'anotador_59684932': 34},
#  frozenset({281, 282}): {'anotador_26827896': 27, 'anotador_59821738': 27},
#  frozenset({1377, 1378}): {'anotador_69243565': 4, 'anotador_59684932': 4},
#  frozenset({1111, 1112, 1113}): {'anotador_72589596': 17,
#   'anotador_59684932': 17,
#   'anotador_69243565': 17},
#  frozenset({421, 422}): {'anotador_46084830': 15, 'anotador_37204582': 15},
#  frozenset({190, 191, 192}): {'anotador_59821738': 36,
#   'anotador_135115': 36,
#   'anotador_26827896': 36},
#  frozenset({1859, 1860}): {'anotador_59821738': 35, 'anotador_26827896': 35},
#  frozenset({460, 461}): {'anotador_135115': 1, 'anotador_26827896': 1},
#  frozenset({273, 274}): {'anotador_26827896': 38, 'anotador_59821738': 38},
#  frozenset({525, 526}): {'anotador_46084830': 15, 'anotador_37204582': 15},
#  frozenset({712, 713}): {'anotador_26827896': 27, 'anotador_59821738': 27},
#  frozenset({810}): {'anotador_37204582': 29},
#  frozenset({1594, 1595}): {'anotador_37219154': 36, 'anotador_27589498': 36},
#  frozenset({432, 433, 434, 435, 436, 437}): {'anotador_135115': 10,
#   'anotador_26827896': 10,
#   'anotador_59821738': 10},
#  frozenset({650, 651, 652}): {'anotador_135115': 36,
#   'anotador_59821738': 36,
#   'anotador_26827896': 36},
#  frozenset({1577, 1578, 1579}): {'anotador_135115': 23,
#   'anotador_26827896': 23,
#   'anotador_59821738': 23},
#  frozenset({1691, 1692, 1693}): {'anotador_135115': 27,
#   'anotador_59821738': 27,
#   'anotador_26827896': 27},
#  frozenset({2263, 2264, 2265}): {'anotador_59684932': 22,
#   'anotador_69243565': 22,
#   'anotador_72589596': 22},
#  frozenset({934}): {'anotador_72589596': 44},
#  frozenset({614, 615, 616}): {'anotador_26827896': 27,
#   'anotador_135115': 27,
#   'anotador_59821738': 27},
#  frozenset({1198, 1199, 1200}): {'anotador_59684932': 19,
#   'anotador_72589596': 19,
#   'anotador_69243565': 19},
#  frozenset({1308, 1309, 1310}): {'anotador_26827896': 27,
#   'anotador_59821738': 21},
#  frozenset({2239}): {'anotador_72589596': 4},
#  frozenset({1024, 1025, 1026}): {'anotador_135115': 12,
#   'anotador_59821738': 12,
#   'anotador_26827896': 12},
#  frozenset({762, 763}): {'anotador_46084830': 3, 'anotador_37204582': 3},
#  frozenset({946}): {'anotador_59684932': 30},
#  frozenset({171, 172, 173}): {'anotador_59821738': 1,
#   'anotador_135115': 1,
#   'anotador_26827896': 1},
#  frozenset({193, 194, 195}): {'anotador_135115': 43,
#   'anotador_26827896': 43,
#   'anotador_59821738': 43},
#  frozenset({2145, 2146, 2147}): {'anotador_72589596': 13,
#   'anotador_69243565': 13,
#   'anotador_59684932': 13},
#  frozenset({686, 687}): {'anotador_26827896': 21, 'anotador_59821738': 21},
#  frozenset({728, 729}): {'anotador_26827896': 38, 'anotador_59821738': 38},
#  frozenset({293, 294}): {'anotador_26827896': 43, 'anotador_59821738': 43},
#  frozenset({1864, 1865, 1866}): {'anotador_59821738': 38,
#   'anotador_26827896': 38,
#   'anotador_135115': 38},
#  frozenset({1924}): {'anotador_135115': 19},
#  frozenset({1349, 1350, 1351}): {'anotador_26827896': 27,
#   'anotador_135115': 27,
#   'anotador_59821738': 27},
#  frozenset({2089, 2090, 2091}): {'anotador_72589596': 44,
#   'anotador_69243565': 44,
#   'anotador_59684932': 44},
#  frozenset({1407, 1408, 1409}): {'anotador_72589596': 24,
#   'anotador_59684932': 24,
#   'anotador_69243565': 24},
#  frozenset({1639, 1640, 1642}): {'anotador_59821738': 32,
#   'anotador_26827896': 32,
#   'anotador_135115': 32},
#  frozenset({1302, 1303}): {'anotador_26827896': 1, 'anotador_59821738': 1},
#  frozenset({174, 175}): {'anotador_26827896': 21, 'anotador_59821738': 21},
#  frozenset({1146, 1147, 1148}): {'anotador_72589596': 25,
#   'anotador_59684932': 25,
#   'anotador_69243565': 34},
#  frozenset({1163, 1164, 1165}): {'anotador_69243565': 44,
#   'anotador_72589596': 44,
#   'anotador_59684932': 44},
#  frozenset({286, 288}): {'anotador_59821738': 32, 'anotador_26827896': 32},
#  frozenset({948, 949}): {'anotador_72589596': 4, 'anotador_59684932': 4},
#  frozenset({830}): {'anotador_46084830': 34},
#  frozenset({1050, 1051}): {'anotador_59821738': 38, 'anotador_26827896': 38},
#  frozenset({1271, 1272, 1273}): {'anotador_59821738': 12,
#   'anotador_26827896': 12,
#   'anotador_135115': 12},
#  frozenset({339, 340, 341}): {'anotador_69243565': 40,
#   'anotador_72589596': 40,
#   'anotador_59684932': 40},
#  frozenset({1541, 1542, 1543}): {'anotador_26827896': 38,
#   'anotador_59821738': 38,
#   'anotador_135115': 38},
#  frozenset({1432, 1433}): {'anotador_26827896': 43, 'anotador_135115': 43},
#  frozenset({406}): {'anotador_37204582': 34},
#  frozenset({774, 775, 776}): {'anotador_26827896': 1,
#   'anotador_135115': 1,
#   'anotador_59821738': 1},
#  frozenset({1503, 1504}): {'anotador_59821738': 36, 'anotador_26827896': 36},
#  frozenset({111, 112, 113}): {'anotador_59821738': 10,
#   'anotador_26827896': 10,
#   'anotador_135115': 10},
#  frozenset({1285}): {'anotador_72589596': 30},
#  frozenset({2045, 2046, 2047}): {'anotador_135115': 36,
#   'anotador_59821738': 36,
#   'anotador_26827896': 36},
#  frozenset({23}): {'anotador_69243565': 34},
#  frozenset({2157, 2158}): {'anotador_37204582': 28, 'anotador_46084830': 28},
#  frozenset({1314, 1316}): {'anotador_26827896': 39, 'anotador_59821738': 39},
#  frozenset({770, 771}): {'anotador_37204582': 29, 'anotador_46084830': 29},
#  frozenset({1777, 1778, 1779}): {'anotador_69243565': 40,
#   'anotador_72589596': 40,
#   'anotador_59684932': 40},
#  frozenset({1798, 1799}): {'anotador_37204582': 28, 'anotador_46084830': 28},
#  frozenset({342, 343, 344}): {'anotador_59684932': 37,
#   'anotador_69243565': 37,
#   'anotador_72589596': 37},
#  frozenset({1220, 1221, 1222}): {'anotador_135115': 36,
#   'anotador_26827896': 36,
#   'anotador_59821738': 36},
#  frozenset({1233}): {'anotador_26827896': 12},
#  frozenset({1530, 1531}): {'anotador_26827896': 35, 'anotador_59821738': 35},
#  frozenset({1117, 1118, 1119}): {'anotador_69243565': 41,
#   'anotador_72589596': 41,
#   'anotador_59684932': 41},
#  frozenset({922, 923, 924, 925}): {'anotador_72589596': 13,
#   'anotador_46084830': 15,
#   'anotador_37204582': 15,
#   'anotador_59684932': 13},
#  frozenset({231, 232}): {'anotador_26827896': 21, 'anotador_59821738': 21},
#  frozenset({1465}): {'anotador_26827896': 35},
#  frozenset({1648, 1649}): {'anotador_26827896': 12, 'anotador_59821738': 12},
#  frozenset({2016, 2017, 2019}): {'anotador_135115': 39,
#   'anotador_59821738': 39,
#   'anotador_26827896': 39},
#  frozenset({1123, 1124, 1125}): {'anotador_69243565': 40,
#   'anotador_72589596': 40,
#   'anotador_59684932': 40},
#  frozenset({1431}): {'anotador_26827896': 12},
#  frozenset({1747, 1748}): {'anotador_26827896': 38, 'anotador_59821738': 38},
#  frozenset({1581}): {'anotador_37204582': 28},
#  frozenset({227, 228}): {'anotador_59821738': 23, 'anotador_26827896': 23},
#  frozenset({2049, 2050, 2052}): {'anotador_135115': 39,
#   'anotador_26827896': 39,
#   'anotador_59821738': 39},
#  frozenset({1877, 1878}): {'anotador_59821738': 21, 'anotador_26827896': 21},
#  frozenset({654, 655, 657, 659}): {'anotador_59821738': 39,
#   'anotador_26827896': 39,
#   'anotador_135115': 39},
#  frozenset({1903}): {'anotador_26827896': 38},
#  frozenset({1694, 1695, 1696}): {'anotador_59821738': 10,
#   'anotador_26827896': 10,
#   'anotador_135115': 10},
#  frozenset({507, 508}): {'anotador_37204582': 3, 'anotador_46084830': 3},
#  frozenset({947}): {'anotador_72589596': 30},
#  frozenset({969, 970, 971}): {'anotador_135115': 36,
#   'anotador_26827896': 36,
#   'anotador_59821738': 36},
#  frozenset({1666, 1667, 1669}): {'anotador_135115': 32,
#   'anotador_59821738': 32,
#   'anotador_26827896': 32},
#  frozenset({378, 379, 380}): {'anotador_26827896': 12,
#   'anotador_59821738': 12,
#   'anotador_135115': 12},
#  frozenset({1979, 1980, 1981}): {'anotador_59821738': 36,
#   'anotador_26827896': 36,
#   'anotador_135115': 36},
#  frozenset({17, 18, 19}): {'anotador_59684932': 6,
#   'anotador_69243565': 6,
#   'anotador_72589596': 6},
#  frozenset({1343, 1344, 1346}): {'anotador_135115': 1,
#   'anotador_59821738': 1,
#   'anotador_26827896': 1},
#  frozenset({606, 607}): {'anotador_59821738': 38, 'anotador_26827896': 38},
#  frozenset({122, 123, 124}): {'anotador_26827896': 27,
#   'anotador_27589498': 27,
#   'anotador_135115': 27},
#  frozenset({2007, 2008}): {'anotador_26827896': 21, 'anotador_59821738': 21},
#  frozenset({2245, 2246, 2247}): {'anotador_72589596': 25,
#   'anotador_59684932': 25,
#   'anotador_69243565': 25},
#  frozenset({1215, 1216}): {'anotador_59821738': 21, 'anotador_26827896': 21},
#  frozenset({1212, 1213, 1214}): {'anotador_135115': 1,
#   'anotador_26827896': 1,
#   'anotador_59821738': 1},
#  frozenset({275, 276}): {'anotador_26827896': 23, 'anotador_59821738': 23},
#  frozenset({64, 65, 66}): {'anotador_59821738': 43,
#   'anotador_135115': 43,
#   'anotador_26827896': 43},
#  frozenset({1416, 1417, 1418}): {'anotador_69243565': 24,
#   'anotador_72589596': 24,
#   'anotador_59684932': 24},
#  frozenset({722, 723}): {'anotador_26827896': 36, 'anotador_59821738': 36},
#  frozenset({888, 889, 890}): {'anotador_59684932': 30,
#   'anotador_69243565': 30,
#   'anotador_72589596': 30},
#  frozenset({1382, 1383, 1384}): {'anotador_59684932': 36,
#   'anotador_69243565': 36,
#   'anotador_72589596': 36},
#  frozenset({319, 320, 321}): {'anotador_72589596': 25,
#   'anotador_59684932': 25,
#   'anotador_69243565': 25},
#  frozenset({1306, 1307}): {'anotador_26827896': 36, 'anotador_59821738': 36},
#  frozenset({1283}): {'anotador_72589596': 36},
#  frozenset({2181, 2182}): {'anotador_37204582': 15, 'anotador_46084830': 15},
#  frozenset({354, 355, 356}): {'anotador_69243565': 44,
#   'anotador_72589596': 44,
#   'anotador_59684932': 44},
#  frozenset({215, 216}): {'anotador_26827896': 39, 'anotador_59821738': 39},
#  frozenset({1707}): {'anotador_26827896': 35},
#  frozenset({1658, 1659, 1660}): {'anotador_26827896': 1,
#   'anotador_135115': 1,
#   'anotador_59821738': 1},
#  frozenset({1610, 1611}): {'anotador_37204582': 34, 'anotador_46084830': 34},
#  frozenset({1180, 1181, 1182}): {'anotador_72589596': 34,
#   'anotador_69243565': 34,
#   'anotador_59684932': 34},
#  frozenset({345, 346, 347}): {'anotador_69243565': 22,
#   'anotador_72589596': 22,
#   'anotador_59684932': 22},
#  frozenset({399, 401}): {'anotador_26827896': 39, 'anotador_135115': 39},
#  frozenset({311, 312}): {'anotador_46084830': 29, 'anotador_37204582': 29},
#  frozenset({1796, 1797}): {'anotador_37204582': 3, 'anotador_46084830': 3},
#  frozenset({2067, 2068, 2069}): {'anotador_72589596': 4,
#   'anotador_69243565': 4,
#   'anotador_59684932': 4},
#  frozenset({404}): {'anotador_26827896': 27},
#  frozenset({680, 681, 682}): {'anotador_27589498': 20,
#   'anotador_37219154': 27},
#  frozenset({1631, 1632, 1633}): {'anotador_135115': 1,
#   'anotador_59821738': 1,
#   'anotador_26827896': 1},
#  frozenset({1703}): {'anotador_26827896': 39},
#  frozenset({1061, 1062}): {'anotador_59821738': 27, 'anotador_26827896': 27},
#  frozenset({2177, 2178}): {'anotador_37204582': 34, 'anotador_46084830': 34},
#  frozenset({543}): {'anotador_37204582': 36},
#  frozenset({700, 701}): {'anotador_26827896': 43, 'anotador_59821738': 43},
#  frozenset({1525, 1527}): {'anotador_26827896': 39, 'anotador_59821738': 39},
#  frozenset({1419, 1420}): {'anotador_69243565': 40, 'anotador_59684932': 40},
#  frozenset({14, 15, 16}): {'anotador_72589596': 17,
#   'anotador_59684932': 17,
#   'anotador_69243565': 17},
#  frozenset({1727, 1728, 1729}): {'anotador_135115': 10,
#   'anotador_59821738': 10,
#   'anotador_26827896': 10},
#  frozenset({2151, 2152}): {'anotador_72589596': 36, 'anotador_59684932': 36},
#  frozenset({1143, 1144}): {'anotador_59684932': 4, 'anotador_72589596': 4},
#  frozenset({965}): {'anotador_26827896': 21},
#  frozenset({1618, 1619}): {'anotador_37204582': 28, 'anotador_46084830': 28},
#  frozenset({136, 137, 138}): {'anotador_26827896': 23,
#   'anotador_135115': 23,
#   'anotador_27589498': 23},
#  frozenset({1322}): {'anotador_26827896': 35},
#  frozenset({199, 200, 201}): {'anotador_26827896': 38,
#   'anotador_59821738': 38,
#   'anotador_135115': 38},
#  frozenset({1037, 1038}): {'anotador_59821738': 21, 'anotador_26827896': 21},
#  frozenset({1059, 1060}): {'anotador_59821738': 21, 'anotador_26827896': 21},
#  frozenset({927}): {'anotador_72589596': 4},
#  frozenset({1622, 1623}): {'anotador_37204582': 36, 'anotador_46084830': 36},
#  frozenset({1705, 1706}): {'anotador_26827896': 39, 'anotador_59821738': 39},
#  frozenset({309, 310}): {'anotador_37204582': 34, 'anotador_46084830': 34},
#  frozenset({1242, 1243, 1244}): {'anotador_26827896': 23,
#   'anotador_59821738': 23,
#   'anotador_135115': 23},
#  frozenset({237, 239}): {'anotador_59821738': 39, 'anotador_26827896': 39},
#  frozenset({2114, 2115, 2116, 2117}): {'anotador_72589596': 34,
#   'anotador_69243565': 25,
#   'anotador_59684932': 25},
#  frozenset({1331, 1332}): {'anotador_37219154': 36, 'anotador_27589498': 36},
#  frozenset({891, 892, 893}): {'anotador_59684932': 44,
#   'anotador_69243565': 44,
#   'anotador_72589596': 44},
#  frozenset({1948, 1949, 1950}): {'anotador_59821738': 36,
#   'anotador_26827896': 36,
#   'anotador_135115': 36},
#  frozenset({2209}): {'anotador_72589596': 34},
#  frozenset({851, 852, 853}): {'anotador_59684932': 36,
#   'anotador_69243565': 36,
#   'anotador_72589596': 36},
#  frozenset({659}): {'anotador_26827896': 39},
#  frozenset({1668, 1670, 1671}): {'anotador_26827896': 39,
#   'anotador_135115': 39,
#   'anotador_59821738': 39},
#  frozenset({513, 514}): {'anotador_37204582': 15, 'anotador_46084830': 15},
#  frozenset({467, 468, 469, 470, 471, 472}): {'anotador_135115': 35,
#   'anotador_59821738': 27,
#   'anotador_26827896': 35},
#  frozenset({1183, 1184, 1185}): {'anotador_72589596': 17,
#   'anotador_69243565': 17,
#   'anotador_59684932': 17},
#  frozenset({630}): {'anotador_26827896': 35},
#  frozenset({935}): {'anotador_72589596': 37},
#  frozenset({1158, 1159, 1160}): {'anotador_69243565': 36,
#   'anotador_72589596': 36,
#   'anotador_59684932': 36},
#  frozenset({828}): {'anotador_46084830': 34},
#  frozenset({1174, 1175, 1176}): {'anotador_59684932': 36,
#   'anotador_72589596': 34,
#   'anotador_69243565': 36},
#  frozenset({183, 186, 187}): {'anotador_135115': 39,
#   'anotador_26827896': 39,
#   'anotador_59821738': 39},
#  frozenset({1967}): {'anotador_26827896': 38},
#  frozenset({920}): {'anotador_72589596': 44},
#  frozenset({1711, 1712, 1713}): {'anotador_135115': 12,
#   'anotador_59821738': 12,
#   'anotador_26827896': 12},
#  frozenset({1764, 1765, 1766}): {'anotador_69243565': 17,
#   'anotador_72589596': 17,
#   'anotador_59684932': 17},
#  frozenset({1477, 1478}): {'anotador_37219154': 21, 'anotador_27589498': 21},
#  frozenset({1550, 1551}): {'anotador_26827896': 21, 'anotador_59821738': 21},
#  frozenset({160, 161, 162}): {'anotador_135115': 12,
#   'anotador_26827896': 12,
#   'anotador_59821738': 12},
#  frozenset({1663, 1664, 1665}): {'anotador_135115': 27,
#   'anotador_59821738': 27,
#   'anotador_26827896': 27},
#  frozenset({1982, 1984, 1986}): {'anotador_59821738': 32,
#   'anotador_26827896': 32,
#   'anotador_135115': 32},
#  frozenset({1733, 1734, 1737}): {'anotador_26827896': 39,
#   'anotador_135115': 39,
#   'anotador_59821738': 39},
#  frozenset({265, 266}): {'anotador_26827896': 35, 'anotador_59821738': 35},
#  frozenset({245, 246}): {'anotador_59821738': 43, 'anotador_26827896': 43},
#  frozenset({2043, 2044}): {'anotador_59821738': 21, 'anotador_26827896': 21},
#  frozenset({168, 169, 170}): {'anotador_135115': 23,
#   'anotador_26827896': 23,
#   'anotador_59821738': 23},
#  frozenset({1155, 1156, 1157}): {'anotador_72589596': 30,
#   'anotador_59684932': 30,
#   'anotador_69243565': 30},
#  frozenset({1359, 1360, 1361}): {'anotador_135115': 32,
#   'anotador_59821738': 32,
#   'anotador_26827896': 32},
#  frozenset({1365, 1366, 1367}): {'anotador_26827896': 43,
#   'anotador_135115': 43,
#   'anotador_59821738': 43},
#  frozenset({1497, 1499}): {'anotador_26827896': 39, 'anotador_59821738': 39},
#  frozenset({1571, 1572, 1573}): {'anotador_59821738': 12,
#   'anotador_135115': 12,
#   'anotador_26827896': 12},
#  frozenset({1588, 1589}): {'anotador_27589498': 2, 'anotador_37219154': 2},
#  frozenset({179, 180, 181}): {'anotador_135115': 10,
#   'anotador_26827896': 10,
#   'anotador_59821738': 10},
#  frozenset({1795}): {'anotador_59821738': 27},
#  frozenset({289, 290}): {'anotador_26827896': 35, 'anotador_59821738': 35},
#  frozenset({1719, 1720, 1721}): {'anotador_135115': 1,
#   'anotador_59821738': 27,
#   'anotador_26827896': 1},
#  frozenset({1879, 1880, 1881}): {'anotador_26827896': 27,
#   'anotador_135115': 27,
#   'anotador_59821738': 27},
#  frozenset({813, 814, 821, 822}): {'anotador_46084830': 3,
#   'anotador_37204582': 3},
#  frozenset({744}): {'anotador_46084830': 15},
#  frozenset({261, 263}): {'anotador_26827896': 39, 'anotador_59821738': 39},
#  frozenset({1427}): {'anotador_135115': 39},
#  frozenset({576, 577, 578}): {'anotador_135115': 23,
#   'anotador_59821738': 23,
#   'anotador_26827896': 23},
#  frozenset({2148}): {'anotador_72589596': 34},
#  frozenset({484}): {'anotador_26827896': 35},
#  frozenset({1544, 1545, 1546}): {'anotador_135115': 23,
#   'anotador_26827896': 23,
#   'anotador_59821738': 1},
#  frozenset({1423}): {'anotador_26827896': 21},
#  frozenset({1686}): {'anotador_135115': 35},
#  frozenset({2032}): {'anotador_26827896': 38},
#  frozenset({867}): {'anotador_72589596': 34},
#  frozenset({544, 545, 546}): {'anotador_59821738': 1,
#   'anotador_135115': 1,
#   'anotador_26827896': 1},
#  frozenset({834}): {'anotador_46084830': 15},
#  frozenset({297, 298}): {'anotador_26827896': 38, 'anotador_59821738': 38},
#  frozenset({503, 504}): {'anotador_37204582': 29, 'anotador_46084830': 29},
#  frozenset({1672, 1673, 1674}): {'anotador_26827896': 36,
#   'anotador_135115': 36,
#   'anotador_59821738': 36},
#  frozenset({1837}): {'anotador_26827896': 38},
#  frozenset({2130, 2131, 2132}): {'anotador_72589596': 44,
#   'anotador_69243565': 44,
#   'anotador_59684932': 44},
#  frozenset({392, 393}): {'anotador_135115': 1, 'anotador_26827896': 1},
#  frozenset({1004}): {'anotador_135115': 39},
#  frozenset({1410, 1411, 1412}): {'anotador_59684932': 24,
#   'anotador_69243565': 24,
#   'anotador_72589596': 24},
#  frozenset({1813, 1814, 1815}): {'anotador_59821738': 27,
#   'anotador_26827896': 27,
#   'anotador_135115': 27},
#  frozenset({1091, 1092}): {'anotador_72589596': 30, 'anotador_59684932': 30},
#  frozenset({493, 494}): {'anotador_46084830': 3, 'anotador_37204582': 3},
#  frozenset({758, 759}): {'anotador_37219154': 23, 'anotador_27589498': 23},
#  frozenset({117, 118, 119}): {'anotador_135115': 1,
#   'anotador_26827896': 1,
#   'anotador_27589498': 2},
#  frozenset({873, 874, 875}): {'anotador_59684932': 25,
#   'anotador_69243565': 25,
#   'anotador_72589596': 25},
#  frozenset({1852, 1854, 1856}): {'anotador_26827896': 32,
#   'anotador_135115': 32,
#   'anotador_59821738': 32},
#  frozenset({1991, 1992, 1993}): {'anotador_135115': 12,
#   'anotador_59821738': 12,
#   'anotador_26827896': 12},
#  frozenset({451}): {'anotador_26827896': 35},
#  frozenset({642, 643, 644}): {'anotador_135115': 1,
#   'anotador_26827896': 1,
#   'anotador_59821738': 1},
#  frozenset({400, 402}): {'anotador_135115': 32, 'anotador_26827896': 32},
#  frozenset({567, 568, 569, 570}): {'anotador_135115': 38,
#   'anotador_59821738': 38,
#   'anotador_26827896': 21},
#  frozenset({427, 428, 429}): {'anotador_135115': 1,
#   'anotador_59821738': 27,
#   'anotador_26827896': 1},
#  frozenset({611, 612, 613}): {'anotador_59821738': 1,
#   'anotador_26827896': 1,
#   'anotador_135115': 1},
#  frozenset({930}): {'anotador_72589596': 34},
#  frozenset({1063, 1064}): {'anotador_26827896': 36, 'anotador_59821738': 36},
#  frozenset({202, 203, 204}): {'anotador_135115': 23,
#   'anotador_26827896': 23,
#   'anotador_59821738': 23},
#  frozenset({424}): {'anotador_72589596': 25},
#  frozenset({211, 212}): {'anotador_59821738': 10, 'anotador_26827896': 10},
#  frozenset({247, 248}): {'anotador_26827896': 12, 'anotador_59821738': 12},
#  frozenset({120, 121}): {'anotador_26827896': 21, 'anotador_27589498': 21},
#  frozenset({779, 780, 781}): {'anotador_135115': 27,
#   'anotador_59821738': 27,
#   'anotador_26827896': 27},
#  frozenset({837, 838, 839}): {'anotador_59684932': 4,
#   'anotador_69243565': 4,
#   'anotador_72589596': 4},
#  frozenset({1240, 1241}): {'anotador_26827896': 12, 'anotador_59821738': 12},
#  frozenset({1404, 1405, 1406}): {'anotador_69243565': 24,
#   'anotador_72589596': 24,
#   'anotador_59684932': 24},
#  frozenset({1806, 1807}): {'anotador_37204582': 34, 'anotador_46084830': 34},
#  frozenset({2000}): {'anotador_26827896': 38},
#  frozenset({2161, 2162}): {'anotador_37204582': 34, 'anotador_46084830': 34},
#  frozenset({1195, 1196, 1197}): {'anotador_69243565': 22,
#   'anotador_59684932': 22,
#   'anotador_72589596': 22},
#  frozenset({1547, 1548, 1549}): {'anotador_135115': 1,
#   'anotador_26827896': 1,
#   'anotador_59821738': 1},
#  frozenset({1429, 1430}): {'anotador_26827896': 39},
#  frozenset({1388, 1389, 1390}): {'anotador_69243565': 17,
#   'anotador_72589596': 17,
#   'anotador_59684932': 17},
#  frozenset({547}): {'anotador_26827896': 21},
#  frozenset({1095, 1096}): {'anotador_59684932': 44, 'anotador_72589596': 44},
#  frozenset({996}): {'anotador_26827896': 21},
#  frozenset({1700, 1702, 1704}): {'anotador_26827896': 32,
#   'anotador_135115': 32,
#   'anotador_59821738': 32},
#  frozenset({351, 352, 353}): {'anotador_72589596': 24,
#   'anotador_59684932': 24,
#   'anotador_69243565': 24},
#  frozenset({1189, 1190, 1191}): {'anotador_72589596': 40,
#   'anotador_69243565': 40,
#   'anotador_59684932': 40},
#  frozenset({1282}): {'anotador_72589596': 4},
#  frozenset({793, 794, 795}): {'anotador_135115': 43,
#   'anotador_59821738': 43,
#   'anotador_26827896': 43},
#  frozenset({1472, 1473, 1474}): {'anotador_26827896': 23,
#   'anotador_135115': 23,
#   'anotador_59821738': 23},
#  frozenset({1933, 1934, 1935}): {'anotador_59821738': 10,
#   'anotador_26827896': 10,
#   'anotador_135115': 10},
#  frozenset({411, 412}): {'anotador_46084830': 28, 'anotador_37204582': 28},
#  frozenset({2186, 2187, 2188}): {'anotador_37204582': 3,
#   'anotador_46084830': 3,
#   'anotador_72589596': 4},
#  frozenset({409, 410}): {'anotador_37204582': 3, 'anotador_46084830': 3},
#  frozenset({596}): {'anotador_26827896': 35},
#  frozenset({2207}): {'anotador_72589596': 44},
#  frozenset({717, 719}): {'anotador_26827896': 32, 'anotador_59821738': 32},
#  frozenset({1910, 1911}): {'anotador_59821738': 21, 'anotador_26827896': 21},
#  frozenset({527, 528}): {'anotador_46084830': 29, 'anotador_37204582': 29},
#  frozenset({582, 583}): {'anotador_59821738': 21, 'anotador_26827896': 21},
#  frozenset({1479, 1480}): {'anotador_27589498': 27, 'anotador_37219154': 27},
#  frozenset({501, 502}): {'anotador_46084830': 34, 'anotador_37204582': 34},
#  frozenset({1385, 1386, 1387}): {'anotador_69243565': 34,
#   'anotador_72589596': 34,
#   'anotador_59684932': 34},
#  frozenset({714, 715}): {'anotador_26827896': 10, 'anotador_59821738': 10},
#  frozenset({791, 792}): {'anotador_26827896': 12, 'anotador_59821738': 12},
#  frozenset({1841, 1842, 1843}): {'anotador_26827896': 1,
#   'anotador_135115': 1,
#   'anotador_59821738': 1},
#  frozenset({1248, 1249}): {'anotador_59821738': 21, 'anotador_26827896': 21},
#  frozenset({932}): {'anotador_72589596': 30},
#  frozenset({1352, 1353, 1354}): {'anotador_26827896': 10,
#   'anotador_135115': 10,
#   'anotador_59821738': 10},
#  frozenset({993, 995}): {'anotador_135115': 1, 'anotador_26827896': 1},
#  frozenset({135}): {'anotador_26827896': 38},
#  frozenset({70, 71, 72}): {'anotador_26827896': 38,
#   'anotador_59821738': 38,
#   'anotador_135115': 38},
#  frozenset({738, 739}): {'anotador_37204582': 36, 'anotador_46084830': 36},
#  frozenset({394}): {'anotador_26827896': 21},
#  frozenset({942, 943}): {'anotador_72589596': 34, 'anotador_59684932': 34},
#  frozenset({131}): {'anotador_26827896': 39},
#  frozenset({1685, 1687, 1688}): {'anotador_59821738': 1,
#   'anotador_26827896': 1,
#   'anotador_135115': 1},
#  frozenset({619, 620, 621}): {'anotador_135115': 36,
#   'anotador_59821738': 36,
#   'anotador_26827896': 36},
#  frozenset({693, 695}): {'anotador_59821738': 39, 'anotador_26827896': 39},
#  frozenset({864, 865, 866}): {'anotador_59684932': 41,
#   'anotador_69243565': 41,
#   'anotador_72589596': 41},
#  frozenset({632, 633, 634}): {'anotador_135115': 12,
#   'anotador_59821738': 12,
#   'anotador_26827896': 12},
#  frozenset({269, 270}): {'anotador_26827896': 43, 'anotador_59821738': 43},
#  frozenset({2026, 2027, 2028}): {'anotador_135115': 38,
#   'anotador_59821738': 38,
#   'anotador_26827896': 38},
#  frozenset({336, 337, 338}): {'anotador_69243565': 41,
#   'anotador_72589596': 41,
#   'anotador_59684932': 41},
#  frozenset({684, 685}): {'anotador_26827896': 1, 'anotador_59821738': 1},
#  frozenset({1808, 1809, 1810}): {'anotador_59821738': 1,
#   'anotador_26827896': 1,
#   'anotador_135115': 1},
#  frozenset({1919, 1921, 1923}): {'anotador_26827896': 39,
#   'anotador_135115': 39,
#   'anotador_59821738': 39},
#  frozenset({1752, 1753, 1754}): {'anotador_69243565': 4,
#   'anotador_72589596': 4,
#   'anotador_59684932': 4},
#  frozenset({2254, 2255, 2256}): {'anotador_69243565': 30,
#   'anotador_72589596': 30,
#   'anotador_59684932': 30},
#  frozenset({571, 572, 573}): {'anotador_135115': 10,
#   'anotador_59821738': 10,
#   'anotador_26827896': 10},
#  frozenset({1518, 1519, 1520}): {'anotador_59821738': 27,
#   'anotador_135115': 27,
#   'anotador_26827896': 27},
#  frozenset({1253, 1254, 1255}): {'anotador_26827896': 10,
#   'anotador_135115': 10,
#   'anotador_59821738': 10},
#  frozenset({1493, 1494}): {'anotador_26827896': 27, 'anotador_59821738': 27},
#  frozenset({1475, 1476}): {'anotador_27589498': 2, 'anotador_37219154': 2},
#  frozenset({978, 979, 980}): {'anotador_135115': 43,
#   'anotador_26827896': 43,
#   'anotador_59821738': 43},
#  frozenset({1044, 1046}): {'anotador_59821738': 32, 'anotador_26827896': 32},
#  frozenset({1849, 1850, 1851}): {'anotador_59821738': 36,
#   'anotador_26827896': 36,
#   'anotador_135115': 36},
#  frozenset({307, 308}): {'anotador_37204582': 36, 'anotador_46084830': 36},
#  frozenset({1012, 1013, 1014}): {'anotador_135115': 27,
#   'anotador_59821738': 27,
#   'anotador_26827896': 27},
#  frozenset({1426}): {'anotador_135115': 32},
#  frozenset({688, 689}): {'anotador_26827896': 27, 'anotador_59821738': 1},
#  frozenset({2242, 2243, 2244}): {'anotador_72589596': 36,
#   'anotador_59684932': 36,
#   'anotador_69243565': 36},
#  frozenset({313}): {'anotador_46084830': 25},
#  frozenset({555, 557, 559}): {'anotador_135115': 32,
#   'anotador_59821738': 32,
#   'anotador_26827896': 32},
#  frozenset({1048, 1049}): {'anotador_59821738': 12, 'anotador_26827896': 12},
#  frozenset({1937, 1938, 1939}): {'anotador_59821738': 23,
#   'anotador_26827896': 23,
#   'anotador_135115': 23},
#  frozenset({157, 158, 159}): {'anotador_135115': 43,
#   'anotador_26827896': 43,
#   'anotador_59821738': 43},
#  frozenset({1616, 1617}): {'anotador_46084830': 3, 'anotador_37204582': 3},
#  frozenset({1976, 1977, 1978}): {'anotador_59821738': 27,
#   'anotador_26827896': 27,
#   'anotador_135115': 27},
#  frozenset({960, 961}): {'anotador_72589596': 44, 'anotador_59684932': 44},
#  frozenset({251, 252}): {'anotador_59821738': 23, 'anotador_26827896': 23},
#  frozenset({803, 804}): {'anotador_37204582': 28, 'anotador_46084830': 28},
#  frozenset({1444, 1445}): {'anotador_26827896': 21, 'anotador_59821738': 21},
#  frozenset({1511, 1512}): {'anotador_26827896': 23, 'anotador_59821738': 1},
#  frozenset({1961, 1962, 1963}): {'anotador_59821738': 38,
#   'anotador_26827896': 38,
#   'anotador_135115': 38},
#  frozenset({2171, 2172}): {'anotador_37204582': 3, 'anotador_46084830': 3},
#  frozenset({944, 945}): {'anotador_72589596': 17, 'anotador_59684932': 17},
#  frozenset({1304, 1305}): {'anotador_26827896': 35, 'anotador_59821738': 35},
#  frozenset({698, 699}): {'anotador_26827896': 36, 'anotador_59821738': 36},
#  frozenset({462, 463}): {'anotador_59821738': 21, 'anotador_26827896': 21},
#  frozenset({1819, 1821, 1823}): {'anotador_135115': 32,
#   'anotador_59821738': 32,
#   'anotador_26827896': 32},
#  frozenset({772, 773}): {'anotador_37204582': 15, 'anotador_46084830': 15},
#  frozenset({831}): {'anotador_46084830': 3},
#  frozenset({1608, 1609}): {'anotador_37204582': 36, 'anotador_46084830': 36},
#  frozenset({801, 802}): {'anotador_37204582': 3, 'anotador_46084830': 3},
#  frozenset({1298, 1299}): {'anotador_46084830': 29, 'anotador_37204582': 29},
#  frozenset({495, 496}): {'anotador_37204582': 28, 'anotador_46084830': 28},
#  frozenset({1773}): {'anotador_69243565': 34},
#  frozenset({2009, 2010, 2011}): {'anotador_59821738': 27,
#   'anotador_26827896': 27,
#   'anotador_135115': 27},
#  frozenset({1466, 1467, 1468}): {'anotador_26827896': 12,
#   'anotador_135115': 12,
#   'anotador_59821738': 12},
#  frozenset({1529}): {'anotador_135115': 39},
#  frozenset({704, 705}): {'anotador_59821738': 38, 'anotador_26827896': 38},
#  frozenset({92, 93, 95}): {'anotador_135115': 32,
#   'anotador_59821738': 32,
#   'anotador_26827896': 32},
#  frozenset({372, 375, 377}): {'anotador_59821738': 32,
#   'anotador_135115': 32,
#   'anotador_26827896': 32},
#  frozenset({519, 520}): {'anotador_46084830': 3, 'anotador_37204582': 3},
#  frozenset({1441, 1442, 1443}): {'anotador_26827896': 1,
#   'anotador_135115': 1,
#   'anotador_59821738': 1},
#  frozenset({1786, 1787, 1788}): {'anotador_69243565': 19,
#   'anotador_72589596': 19,
#   'anotador_59684932': 19},
#  frozenset({1612, 1613}): {'anotador_37204582': 29, 'anotador_46084830': 29},
#  frozenset({1437, 1438}): {'anotador_26827896': 10, 'anotador_135115': 10},
#  frozenset({1558, 1560, 1562}): {'anotador_26827896': 32,
#   'anotador_59821738': 32,
#   'anotador_135115': 32},
#  frozenset({1021, 1022, 1023}): {'anotador_135115': 36,
#   'anotador_59821738': 36,
#   'anotador_26827896': 36},
#  frozenset({75, 76, 77}): {'anotador_59821738': 10,
#   'anotador_135115': 10,
#   'anotador_26827896': 10},
#  frozenset({782, 783, 787}): {'anotador_26827896': 32,
#   'anotador_59821738': 32,
#   'anotador_135115': 32},
#  frozenset({1853, 1855, 1857}): {'anotador_135115': 39,
#   'anotador_59821738': 39,
#   'anotador_26827896': 39},
#  frozenset({1223, 1226, 1228}): {'anotador_26827896': 32,
#   'anotador_59821738': 32,
#   'anotador_135115': 32},
#  frozenset({1614, 1615}): {'anotador_37204582': 15, 'anotador_46084830': 15},
#  frozenset({648, 649}): {'anotador_59821738': 21, 'anotador_26827896': 21},
#  frozenset({1170}): {'anotador_72589596': 34},
#  frozenset({39, 40, 41}): {'anotador_69243565': 24,
#   'anotador_72589596': 24,
#   'anotador_59684932': 24},
#  frozenset({1358}): {'anotador_26827896': 39},
#  frozenset({1641, 1643, 1644}): {'anotador_26827896': 39,
#   'anotador_135115': 39,
#   'anotador_59821738': 39},
#  frozenset({1177, 1178, 1179}): {'anotador_69243565': 25,
#   'anotador_59684932': 25,
#   'anotador_72589596': 25},
#  frozenset({1565, 1566, 1567}): {'anotador_135115': 36,
#   'anotador_26827896': 36,
#   'anotador_59821738': 36},
#  frozenset({1574, 1575, 1576}): {'anotador_59821738': 38,
#   'anotador_135115': 38,
#   'anotador_26827896': 38},
#  frozenset({2124, 2125, 2126}): {'anotador_72589596': 30,
#   'anotador_69243565': 30,
#   'anotador_59684932': 30},
#  frozenset({2218, 2219}): {'anotador_59821738': 21, 'anotador_26827896': 21},
#  frozenset({182, 184, 185}): {'anotador_59821738': 32,
#   'anotador_135115': 32,
#   'anotador_26827896': 32},
#  frozenset({1007, 1008, 1009}): {'anotador_59821738': 1,
#   'anotador_26827896': 1,
#   'anotador_135115': 1},
#  frozenset({1816, 1817, 1818}): {'anotador_26827896': 36,
# ...
#  frozenset({360}): {'anotador_69243565': 34},
#  frozenset({1256, 1257, 1258}): {'anotador_135115': 35,
#   'anotador_26827896': 35,
#   'anotador_59821738': 35},
#  frozenset({1421, 1422}): {'anotador_26827896': 1, 'anotador_135115': 1},
#  frozenset({2173, 2174}): {'anotador_37204582': 28, 'anotador_46084830': 28},
#  frozenset({1925, 1926}): {'anotador_59821738': 35, 'anotador_26827896': 35},
#  frozenset({1538, 1539, 1540}): {'anotador_135115': 12,
#   'anotador_26827896': 12,
#   'anotador_59821738': 12},
#  frozenset({1994, 1995, 1996}): {'anotador_59821738': 38,
#   'anotador_26827896': 38,
#   'anotador_135115': 38},
#  frozenset({625, 626, 627}): {'anotador_135115': 39,
#   'anotador_59821738': 39,
#   'anotador_26827896': 39},
#  frozenset({1552, 1553, 1554}): {'anotador_135115': 27,
#   'anotador_26827896': 27,
#   'anotador_59821738': 27},
#  frozenset({2153, 2154}): {'anotador_59684932': 25, 'anotador_72589596': 25},
#  frozenset({1054, 1055}): {'anotador_59821738': 38, 'anotador_26827896': 38},
#  frozenset({1169}): {'anotador_72589596': 34},
#  frozenset({1722, 1723}): {'anotador_59821738': 21, 'anotador_26827896': 21},
#  frozenset({1521, 1522, 1523}): {'anotador_135115': 10,
#   'anotador_26827896': 10,
#   'anotador_59821738': 10},
#  frozenset({106, 107, 108}): {'anotador_135115': 38,
#   'anotador_59821738': 38,
#   'anotador_26827896': 38},
#  frozenset({603, 604, 605}): {'anotador_135115': 10,
#   'anotador_59821738': 10,
#   'anotador_26827896': 10},
#  frozenset({333, 334, 335}): {'anotador_59684932': 30,
#   'anotador_69243565': 30,
#   'anotador_72589596': 30},
#  frozenset({485, 486, 487}): {'anotador_135115': 12,
#   'anotador_59821738': 12,
#   'anotador_26827896': 12},
#  frozenset({1871, 1872, 1873}): {'anotador_59821738': 23,
#   'anotador_26827896': 23,
#   'anotador_135115': 23},
#  frozenset({1265, 1266}): {'anotador_26827896': 39, 'anotador_59821738': 39},
#  frozenset({662}): {'anotador_59821738': 43},
#  frozenset({132, 133, 134}): {'anotador_26827896': 36,
#   'anotador_135115': 36,
#   'anotador_27589498': 36},
#  frozenset({1368}): {'anotador_135115': 39},
#  frozenset({1355, 1356, 1357}): {'anotador_26827896': 36,
#   'anotador_135115': 36,
#   'anotador_59821738': 36},
#  frozenset({584, 585, 586}): {'anotador_59821738': 27,
#   'anotador_26827896': 27,
#   'anotador_135115': 27},
#  frozenset({50, 51, 52}): {'anotador_59821738': 27,
#   'anotador_135115': 27,
#   'anotador_26827896': 27},
#  frozenset({928}): {'anotador_72589596': 36},
#  frozenset({98, 99}): {'anotador_59821738': 35, 'anotador_26827896': 35},
#  frozenset({209, 210}): {'anotador_59821738': 27, 'anotador_26827896': 27},
#  frozenset({826}): {'anotador_46084830': 34},
#  frozenset({395, 396}): {'anotador_135115': 27, 'anotador_26827896': 27},
#  frozenset({548, 549, 550, 551}): {'anotador_135115': 27,
#   'anotador_59821738': 27,
#   'anotador_26827896': 35},
#  frozenset({937}): {'anotador_59684932': 4},
#  frozenset({1335, 1336}): {'anotador_27589498': 21, 'anotador_37219154': 21},
#  frozenset({2149, 2150}): {'anotador_72589596': 4, 'anotador_59684932': 4},
#  frozenset({2229, 2230, 2231}): {'anotador_135115': 43,
#   'anotador_59821738': 43,
#   'anotador_26827896': 43},
#  frozenset({696, 697}): {'anotador_26827896': 35, 'anotador_59821738': 35},
#  frozenset({1894, 1895, 1896}): {'anotador_135115': 12,
#   'anotador_59821738': 12,
#   'anotador_26827896': 12},
#  frozenset({2101, 2102, 2103}): {'anotador_72589596': 19,
#   'anotador_69243565': 19,
#   'anotador_59684932': 19},
#  frozenset({622, 623, 624}): {'anotador_59821738': 32,
#   'anotador_135115': 32,
#   'anotador_26827896': 32},
#  frozenset({824}): {'anotador_46084830': 34},
#  frozenset({1327, 1328}): {'anotador_27589498': 21, 'anotador_37219154': 21},
#  frozenset({2033, 2034, 2035}): {'anotador_135115': 23,
#   'anotador_59821738': 23,
#   'anotador_26827896': 23},
#  frozenset({815, 816}): {'anotador_46084830': 28, 'anotador_37204582': 28},
#  frozenset({217, 218}): {'anotador_59821738': 35, 'anotador_26827896': 35},
#  frozenset({1897, 1898, 1899}): {'anotador_59821738': 38,
#   'anotador_26827896': 38,
#   'anotador_135115': 38},
#  frozenset({1072, 1073}): {'anotador_59821738': 38, 'anotador_26827896': 38},
#  frozenset({2004, 2005, 2006}): {'anotador_135115': 1,
#   'anotador_59821738': 1,
#   'anotador_26827896': 1},
#  frozenset({788, 789, 790}): {'anotador_59821738': 36,
#   'anotador_135115': 36,
#   'anotador_26827896': 36},
#  frozenset({127, 128, 130}): {'anotador_26827896': 32,
#   'anotador_27589498': 32,
#   'anotador_135115': 32},
#  frozenset({860}): {'anotador_69243565': 17},
#  frozenset({45, 46, 47}): {'anotador_26827896': 1,
#   'anotador_135115': 1,
#   'anotador_59821738': 1},
#  frozenset({381, 382, 383}): {'anotador_135115': 38,
#   'anotador_26827896': 38,
#   'anotador_59821738': 38},
#  frozenset({1268, 1269, 1270}): {'anotador_26827896': 43,
#   'anotador_135115': 43,
#   'anotador_59821738': 43},
#  frozenset({2012, 2013, 2014}): {'anotador_59821738': 36,
#   'anotador_26827896': 36,
#   'anotador_135115': 36},
#  frozenset({2086, 2087, 2088}): {'anotador_59684932': 41,
#   'anotador_72589596': 41,
#   'anotador_69243565': 41},
#  frozenset({710, 711}): {'anotador_26827896': 21, 'anotador_59821738': 21},
#  frozenset({894, 895, 896}): {'anotador_72589596': 41,
#   'anotador_59684932': 41,
#   'anotador_69243565': 41},
#  frozenset({42, 43, 44}): {'anotador_59684932': 44,
#   'anotador_69243565': 44,
#   'anotador_72589596': 44},
#  frozenset({1237, 1238, 1239}): {'anotador_135115': 10,
#   'anotador_26827896': 10,
#   'anotador_59821738': 10},
#  frozenset({2227, 2228}): {'anotador_59821738': 39, 'anotador_26827896': 39},
#  frozenset({1828, 1829, 1830}): {'anotador_26827896': 12,
#   'anotador_135115': 12,
#   'anotador_59821738': 12},
#  frozenset({2223}): {'anotador_26827896': 39},
#  frozenset({1401, 1402, 1403}): {'anotador_69243565': 44,
#   'anotador_72589596': 44,
#   'anotador_59684932': 44},
#  frozenset({2048, 2051, 2053}): {'anotador_135115': 32,
#   'anotador_26827896': 32,
#   'anotador_59821738': 32},
#  frozenset({1555, 1556, 1557}): {'anotador_135115': 10,
#   'anotador_26827896': 10,
#   'anotador_59821738': 10},
#  frozenset({331, 332}): {'anotador_69243565': 6, 'anotador_59684932': 6},
#  frozenset({1974, 1975}): {'anotador_59821738': 21, 'anotador_26827896': 21},
#  frozenset({479, 480}): {'anotador_26827896': 35, 'anotador_59821738': 27},
#  frozenset({842, 843, 844}): {'anotador_59684932': 25,
#   'anotador_69243565': 25,
#   'anotador_72589596': 25},
#  frozenset({1952, 1954, 1956}): {'anotador_59821738': 39,
#   'anotador_26827896': 39,
#   'anotador_135115': 39},
#  frozenset({1006}): {'anotador_26827896': 39},
#  frozenset({1152, 1153, 1154}): {'anotador_72589596': 17,
#   'anotador_59684932': 17,
#   'anotador_69243565': 17},
#  frozenset({556, 558, 560}): {'anotador_135115': 39,
#   'anotador_59821738': 39,
#   'anotador_26827896': 39},
#  frozenset({972, 975, 977}): {'anotador_59821738': 32,
#   'anotador_135115': 32,
#   'anotador_26827896': 32},
#  frozenset({809}): {'anotador_46084830': 29},
#  frozenset({1462}): {'anotador_135115': 39},
#  frozenset({1882, 1883, 1884}): {'anotador_59821738': 36,
#   'anotador_26827896': 36,
#   'anotador_135115': 36},
#  frozenset({2062, 2063}): {'anotador_59821738': 38, 'anotador_26827896': 38},
#  frozenset({373, 374, 376}): {'anotador_59821738': 39,
#   'anotador_135115': 39,
#   'anotador_26827896': 39},
#  frozenset({1940, 1941, 1942}): {'anotador_59821738': 1,
#   'anotador_26827896': 1,
#   'anotador_135115': 1},
#  frozenset({777, 778}): {'anotador_59821738': 21, 'anotador_26827896': 21},
#  frozenset({166, 167}): {'anotador_26827896': 38, 'anotador_59821738': 38},
#  frozenset({1058}): {'anotador_26827896': 1},
#  frozenset({1825}): {'anotador_135115': 19},
#  frozenset({56, 58, 61}): {'anotador_135115': 32,
#   'anotador_26827896': 32,
#   'anotador_59821738': 32},
#  frozenset({2057, 2058, 2059}): {'anotador_135115': 12,
#   'anotador_59821738': 12,
#   'anotador_26827896': 12},
#  frozenset({94, 96, 97}): {'anotador_135115': 39,
#   'anotador_59821738': 39,
#   'anotador_26827896': 39},
#  frozenset({103, 104, 105}): {'anotador_59821738': 12,
#   'anotador_26827896': 12,
#   'anotador_135115': 15},
#  frozenset({1606, 1607}): {'anotador_37204582': 25, 'anotador_46084830': 25},
#  frozenset({2133, 2134, 2135}): {'anotador_72589596': 24,
#   'anotador_69243565': 24,
#   'anotador_59684932': 24},
#  frozenset({423}): {'anotador_72589596': 4},
#  frozenset({807, 808}): {'anotador_46084830': 15, 'anotador_37204582': 15},
#  frozenset({1957}): {'anotador_135115': 19},
#  frozenset({2213, 2214}): {'anotador_59821738': 35, 'anotador_26827896': 35},
#  frozenset({876, 877, 878}): {'anotador_59684932': 34,
#   'anotador_69243565': 34,
#   'anotador_72589596': 34},
#  frozenset({1274, 1275}): {'anotador_26827896': 36, 'anotador_135115': 36},
#  frozenset({223, 224}): {'anotador_26827896': 12, 'anotador_59821738': 12},
#  frozenset({1590, 1591}): {'anotador_37219154': 21, 'anotador_27589498': 21},
#  frozenset({1513, 1514, 1515}): {'anotador_135115': 1,
#   'anotador_26827896': 1,
#   'anotador_59821738': 27},
#  frozenset({441, 442, 443}): {'anotador_59821738': 32,
#   'anotador_26827896': 32,
#   'anotador_135115': 30},
#  frozenset({1300, 1301}): {'anotador_46084830': 15, 'anotador_37204582': 15},
#  frozenset({1027, 1028, 1029}): {'anotador_135115': 43,
#   'anotador_59821738': 43,
#   'anotador_26827896': 43},
#  frozenset({348, 349, 350}): {'anotador_69243565': 19,
#   'anotador_72589596': 19,
#   'anotador_59684932': 19},
#  frozenset({639, 640, 641}): {'anotador_59821738': 23,
#   'anotador_26827896': 23,
#   'anotador_135115': 23},
#  frozenset({397, 398}): {'anotador_135115': 36, 'anotador_26827896': 36},
#  frozenset({768, 769}): {'anotador_37204582': 34, 'anotador_46084830': 34},
#  frozenset({1276, 1278}): {'anotador_26827896': 38, 'anotador_59821738': 38},
#  frozenset({155, 156}): {'anotador_26827896': 39, 'anotador_59821738': 39},
#  frozenset({690, 691}): {'anotador_26827896': 10, 'anotador_59821738': 10},
#  frozenset({1036}): {'anotador_26827896': 1},
#  frozenset({1989, 1990}): {'anotador_59821738': 35, 'anotador_26827896': 35},
#  frozenset({2107}): {'anotador_72589596': 34},
#  frozenset({1234, 1235, 1236}): {'anotador_135115': 38,
#   'anotador_26827896': 38,
#   'anotador_59821738': 38},
#  frozenset({1800, 1801}): {'anotador_37204582': 25, 'anotador_46084830': 25},
#  frozenset({259, 260}): {'anotador_26827896': 10, 'anotador_59821738': 10},
#  frozenset({907, 908, 909}): {'anotador_46084830': 25,
#   'anotador_37204582': 25,
#   'anotador_59684932': 25},
#  frozenset({1041, 1042}): {'anotador_59821738': 36, 'anotador_26827896': 36},
#  frozenset({11, 12, 13}): {'anotador_59684932': 34,
#   'anotador_69243565': 34,
#   'anotador_72589596': 34},
#  frozenset({1446, 1447, 1448, 1449}): {'anotador_135115': 27,
#   'anotador_59821738': 27,
#   'anotador_26827896': 27},
#  frozenset({1584}): {'anotador_37204582': 34},
#  frozenset({692, 694}): {'anotador_26827896': 32, 'anotador_59821738': 32},
#  frozenset({537, 538}): {'anotador_37204582': 15, 'anotador_46084830': 15},
#  frozenset({1701}): {'anotador_135115': 39},
#  frozenset({2197, 2198, 2199}): {'anotador_37204582': 34,
#   'anotador_72589596': 34,
#   'anotador_46084830': 34},
#  frozenset({1245, 1246, 1247}): {'anotador_135115': 1,
#   'anotador_59821738': 1,
#   'anotador_26827896': 1},
#  frozenset({660, 661}): {'anotador_59821738': 35, 'anotador_26827896': 35},
#  frozenset({1892, 1893}): {'anotador_59821738': 35, 'anotador_26827896': 35},
#  frozenset({2260, 2261, 2262}): {'anotador_72589596': 37,
#   'anotador_59684932': 37,
#   'anotador_69243565': 37},
#  frozenset({369, 370, 371}): {'anotador_135115': 36,
#   'anotador_26827896': 36,
#   'anotador_59821738': 36},
#  frozenset({1783, 1784, 1785}): {'anotador_72589596': 22,
#   'anotador_59684932': 22,
#   'anotador_69243565': 22},
#  frozenset({1279, 1280, 1281}): {'anotador_135115': 23,
#   'anotador_59821738': 23,
#   'anotador_26827896': 23},
#  frozenset({600, 601, 602}): {'anotador_135115': 38,
#   'anotador_59821738': 38,
#   'anotador_26827896': 38},
#  frozenset({53, 54, 55}): {'anotador_59821738': 36,
#   'anotador_135115': 36,
#   'anotador_26827896': 36},
#  frozenset({990, 991, 992}): {'anotador_59821738': 23,
#   'anotador_135115': 23,
#   'anotador_26827896': 23},
#  frozenset({575}): {'anotador_26827896': 21},
#  frozenset({754}): {'anotador_37219154': 32},
#  frozenset({1289, 1290}): {'anotador_46084830': 36, 'anotador_37204582': 36},
#  frozenset({366, 367, 368}): {'anotador_59821738': 27,
#   'anotador_135115': 27,
#   'anotador_26827896': 27},
#  frozenset({1568, 1569, 1570}): {'anotador_135115': 43,
#   'anotador_26827896': 43,
#   'anotador_59821738': 43},
#  frozenset({1192, 1193, 1194}): {'anotador_72589596': 37,
#   'anotador_69243565': 37,
#   'anotador_59684932': 37},
#  frozenset({1626, 1627}): {'anotador_37204582': 29, 'anotador_46084830': 29},
#  frozenset({1826, 1827}): {'anotador_59821738': 35, 'anotador_26827896': 35},
#  frozenset({1983, 1985, 1987}): {'anotador_26827896': 39,
#   'anotador_135115': 39,
#   'anotador_59821738': 39},
#  frozenset({2092, 2093, 2094}): {'anotador_72589596': 24,
#   'anotador_69243565': 24,
#   'anotador_59684932': 24},
#  frozenset({2185}): {'anotador_46084830': 25},
#  frozenset({861, 862, 863}): {'anotador_59684932': 44,
#   'anotador_69243565': 44,
#   'anotador_72589596': 44},
#  frozenset({430, 431}): {'anotador_26827896': 21, 'anotador_59821738': 21},
#  frozenset({720, 721}): {'anotador_26827896': 35, 'anotador_59821738': 35},
#  frozenset({2111, 2112, 2113}): {'anotador_69243565': 36,
#   'anotador_59684932': 36,
#   'anotador_72589596': 36},
#  frozenset({478}): {'anotador_26827896': 39},
#  frozenset({1918, 1920, 1922}): {'anotador_59821738': 32,
#   'anotador_26827896': 32,
#   'anotador_135115': 32},
#  frozenset({36, 37, 38}): {'anotador_59684932': 22,
#   'anotador_69243565': 22,
#   'anotador_72589596': 22},
#  frozenset({1171, 1172, 1173}): {'anotador_72589596': 4,
#   'anotador_69243565': 4,
#   'anotador_59684932': 4},
#  frozenset({488, 489}): {'anotador_59821738': 38, 'anotador_26827896': 38},
#  frozenset({2179, 2180}): {'anotador_37204582': 36, 'anotador_46084830': 36},
#  frozenset({257, 258}): {'anotador_59821738': 27, 'anotador_26827896': 27},
#  frozenset({2022, 2023}): {'anotador_26827896': 35, 'anotador_59821738': 35},
#  frozenset({672, 673}): {'anotador_27589498': 0, 'anotador_37219154': 0},
#  frozenset({541, 542}): {'anotador_37204582': 34, 'anotador_46084830': 34},
#  frozenset({1078, 1079}): {'anotador_59821738': 23, 'anotador_26827896': 23},
#  frozenset({1394, 1395, 1396}): {'anotador_69243565': 30,
#   'anotador_72589596': 30,
#   'anotador_59684932': 30},
#  frozenset({1296, 1297}): {'anotador_46084830': 34, 'anotador_37204582': 34},
#  frozenset({1780, 1781, 1782}): {'anotador_69243565': 37,
#   'anotador_72589596': 37,
#   'anotador_59684932': 37},
#  frozenset({2056}): {'anotador_59821738': 43},
#  frozenset({1487, 1488}): {'anotador_27589498': 23, 'anotador_37219154': 23},
#  frozenset({2192, 2193}): {'anotador_37204582': 28, 'anotador_46084830': 28},
#  frozenset({952, 953}): {'anotador_72589596': 25, 'anotador_59684932': 25},
#  frozenset({747, 748}): {'anotador_27589498': 21, 'anotador_37219154': 21},
#  frozenset({1141, 1142}): {'anotador_69243565': 34, 'anotador_72589596': 34},
#  frozenset({882, 883, 884}): {'anotador_59684932': 36,
#   'anotador_69243565': 36,
#   'anotador_72589596': 36},
#  frozenset({1592, 1593}): {'anotador_37219154': 27, 'anotador_27589498': 27},
#  frozenset({425}): {'anotador_72589596': 36},
#  frozenset({475, 476}): {'anotador_135115': 39, 'anotador_26827896': 39},
#  frozenset({1730, 1731, 1732}): {'anotador_26827896': 36,
#   'anotador_135115': 36,
#   'anotador_59821738': 36},
#  frozenset({1318}): {'anotador_26827896': 39},
#  frozenset({1291, 1292}): {'anotador_46084830': 28, 'anotador_37204582': 28},
#  frozenset({473, 474, 477}): {'anotador_26827896': 32, 'anotador_135115': 32},
#  frozenset({505, 506}): {'anotador_46084830': 15, 'anotador_37204582': 15},
#  frozenset({4333, 4334}): {'anotador_69243565': 34, 'anotador_72589596': 34},
#  frozenset({3717}): {'anotador_69243565': 17},
#  frozenset({2416, 2417, 2420}): {'anotador_135115': 32,
#   'anotador_59821738': 32,
#   'anotador_26827896': 32},
#  frozenset({3313}): {'anotador_72589596': 34},
#  frozenset({3287}): {'anotador_59684932': 23},
#  ...}

# %%
df_krippendorff = pd.DataFrame.from_dict(dict_krippendorff)
df_krippendorff
# Out:
#                    (1217, 1218, 1219)  (1536, 1537, 1535)  (1930, 1931, 1932)  \
# anotador_135115                  27.0                43.0                38.0
# anotador_26827896                27.0                43.0                38.0
# anotador_59821738                27.0                43.0                38.0
# anotador_69243565                 NaN                 NaN                 NaN
# anotador_72589596                 NaN                 NaN                 NaN
# anotador_59684932                 NaN                 NaN                 NaN
# anotador_46084830                 NaN                 NaN                 NaN
# anotador_37204582                 NaN                 NaN                 NaN
# anotador_37219154                 NaN                 NaN                 NaN
# anotador_27589498                 NaN                 NaN                 NaN
# anotador_86273494                 NaN                 NaN                 NaN
#
#                    (1997, 1998, 1999)  (1104, 1102, 1103)  (413, 414)  \
# anotador_135115                  10.0                 NaN         NaN
# anotador_26827896                10.0                 NaN         NaN
# anotador_59821738                10.0                 NaN         NaN
# anotador_69243565                 NaN                 4.0         NaN
# anotador_72589596                 NaN                25.0         NaN
# anotador_59684932                 NaN                25.0         NaN
# anotador_46084830                 NaN                 NaN        25.0
# anotador_37204582                 NaN                 NaN        25.0
# anotador_37219154                 NaN                 NaN         NaN
# anotador_27589498                 NaN                 NaN         NaN
# anotador_86273494                 NaN                 NaN         NaN
#
#                    (552, 553, 554)  (277, 278)  (1000, 999)  (1069)  ...  \
# anotador_135115               36.0         NaN         36.0     NaN  ...
# anotador_26827896             36.0         1.0         36.0    35.0  ...
# anotador_59821738             36.0         1.0          NaN     NaN  ...
# anotador_69243565              NaN         NaN          NaN     NaN  ...
# anotador_72589596              NaN         NaN          NaN     NaN  ...
# anotador_59684932              NaN         NaN          NaN     NaN  ...
# anotador_46084830              NaN         NaN          NaN     NaN  ...
# anotador_37204582              NaN         NaN          NaN     NaN  ...
# anotador_37219154              NaN         NaN          NaN     NaN  ...
# anotador_27589498              NaN         NaN          NaN     NaN  ...
# anotador_86273494              NaN         NaN          NaN     NaN  ...
#
#                    (27493)  (27593, 27594)  (26394, 26395)  \
# anotador_135115        NaN             NaN             NaN
# anotador_26827896      NaN             NaN             NaN
# anotador_59821738      NaN             NaN             NaN
# anotador_69243565      NaN             NaN             NaN
# anotador_72589596      NaN             NaN             NaN
# anotador_59684932      NaN             NaN             NaN
# anotador_46084830     29.0            34.0            25.0
# anotador_37204582      NaN            34.0            25.0
# anotador_37219154      NaN             NaN             NaN
# anotador_27589498      NaN             NaN             NaN
# anotador_86273494      NaN             NaN             NaN
#
#                    (26153, 26154, 26155, 26156)  (25801)  (25883, 25884)  \
# anotador_135115                             NaN      NaN             NaN
# anotador_26827896                           NaN      NaN             NaN
# anotador_59821738                           NaN     32.0             NaN
# anotador_69243565                           NaN      NaN             NaN
# anotador_72589596                           NaN      NaN             NaN
# anotador_59684932                           NaN      NaN             NaN
# anotador_46084830                          25.0      NaN            34.0
# anotador_37204582                          25.0      NaN            34.0
# anotador_37219154                           NaN      NaN             NaN
# anotador_27589498                           NaN      NaN             NaN
# anotador_86273494                           NaN      NaN             NaN
#
#                    (24968, 24967)  (27184, 27185, 27183)  \
# anotador_135115               NaN                    NaN
# anotador_26827896             NaN                    NaN
# anotador_59821738             NaN                    NaN
# anotador_69243565             NaN                   36.0
# anotador_72589596             NaN                   36.0
# anotador_59684932             NaN                   36.0
# anotador_46084830             NaN                    NaN
# anotador_37204582             NaN                    NaN
# anotador_37219154            23.0                    NaN
# anotador_27589498            23.0                    NaN
# anotador_86273494             NaN                    NaN
#
#                    (27365, 27366, 27367)  (26436, 26437, 26438)
# anotador_135115                      NaN                    NaN
# anotador_26827896                    NaN                    NaN
# anotador_59821738                    NaN                    NaN
# anotador_69243565                   22.0                   41.0
# anotador_72589596                   22.0                   41.0
# anotador_59684932                   22.0                   41.0
# anotador_46084830                    NaN                    NaN
# anotador_37204582                    NaN                    NaN
# anotador_37219154                    NaN                    NaN
# anotador_27589498                    NaN                    NaN
# anotador_86273494                    NaN                    NaN
#
# [11 rows x 12784 columns]

# %%
import krippendorff
alpha = krippendorff.alpha(reliability_data=df_krippendorff, level_of_measurement='nominal')
alpha
# Out:
# 0.9730289497472199

# %% [markdown]
# # Número de anotações por tipo de entidade

# %%
df_with_metrics['tipo_ent'].value_counts()
# Out:
# processo_gdf                        2570
# orgao_contratante                   1972
# numero_contrato                     1724
# nome_responsavel                    1183
# numero_licitacao                    1104
# entidade_contratada                 1084
# EXTRATO_CONTRATO                    1083
# objeto_contrato                     1039
# objeto_licitacao                     951
# vigencia_contrato                    938
# sistema_compras                      900
# AVISO_LICITACAO                      873
# tipo_objeto                          873
# modalidade_licitacao                 830
# fonte_recurso                        801
# valor_contrato                       800
# orgao_licitante                      774
# data_abertura_licitacao              758
# data_assinatura_contrato             726
# programa_trabalho                    712
# nota_empenho                         680
# numero_termo_aditivo                 628
# codigo_licitacao_sistema_compras     611
# EXTRATO_ADITAMENTO_CONTRATUAL        607
# objeto_aditamento_contratual         606
# natureza_despesa                     564
# data_escrito                         560
# valor_estimado_contratacao           560
# unidade_orcamentaria                 558
# cnpj_entidade_contratada             225
# codigo_siggo                         141
# AVISO_SUSPENSAO_LICITACAO             84
# cnpj_orgao_contratante                71
# identificacao_ocorrencia              33
# AVISO_ANUL_REV_LICITACAO              30
# decisao_tcdf                          19
# objeto_convenio                       11
# entidade_convenente                   10
# vigencia_convenio                      9
# EXTRATO_CONVENIO                       9
# numero_convenio                        9
# data_assinatura_convenio               8
# orgao_concedente                       7
# cnpj_entidade_convenente               4
# valor_convenio                         3
# cnpj_orgao_concedente                  1
# Name: tipo_ent, dtype: int64

# %% [markdown]
# # Escreve as linhas da tabela de resultados para o relatório

# %%
import re
for entity_type in df_with_metrics['tipo_ent'].unique():
    escaped_entity_type = re.sub(r'_', r'\\_', entity_type)
    edit_distance_mean  = f"{metrics_per_type[entity_type]['edit_distance']['mean']:.0f}"
    edit_distance_std   = f"{metrics_per_type[entity_type]['edit_distance']['std']:.0f}"
    jaccard_index_mean  = f"{metrics_per_type[entity_type]['jaccard_index']['mean']:.1f}"
    jaccard_index_std   = f"{metrics_per_type[entity_type]['jaccard_index']['std']:.1f}"
    cos_sim_tfidf_mean  = f"{metrics_per_type[entity_type]['cos_sim_tfidf']['mean']:.1f}"
    cos_sim_tfidf_std   = f"{metrics_per_type[entity_type]['cos_sim_tfidf']['std']:.1f}"
    num_annotations     = df_with_metrics['tipo_ent'].value_counts()[entity_type]
    print(f"{escaped_entity_type:<36}"
          f"& $ {edit_distance_mean:<4}\\pm {edit_distance_std:<4}$      "
          f"& $ {jaccard_index_mean:<4}\\pm {jaccard_index_std:<4}$  "
          f"& $ {cos_sim_tfidf_mean:<4}\\pm {cos_sim_tfidf_std:<4}$ "
          f"& $ {num_annotations:<5}$   \\\\ \\hline")
# Out:
# EXTRATO\_CONTRATO                   & $ 148 \pm 486 $      & $ 0.9 \pm 0.3 $  & $ 0.9 \pm 0.3 $ & $ 1083 $   \\ \hline
# processo\_gdf                       & $ 1   \pm 5   $      & $ 0.9 \pm 0.2 $  & $ 0.9 \pm 0.2 $ & $ 2570 $   \\ \hline
# numero\_contrato                    & $ 2   \pm 3   $      & $ 0.8 \pm 0.3 $  & $ 0.8 \pm 0.3 $ & $ 1724 $   \\ \hline
# data\_assinatura\_contrato          & $ 1   \pm 3   $      & $ 0.9 \pm 0.3 $  & $ 0.9 \pm 0.3 $ & $ 726  $   \\ \hline
# orgao\_contratante                  & $ 8   \pm 17  $      & $ 0.7 \pm 0.4 $  & $ 0.7 \pm 0.4 $ & $ 1972 $   \\ \hline
# entidade\_contratada                & $ 6   \pm 13  $      & $ 0.8 \pm 0.4 $  & $ 0.8 \pm 0.3 $ & $ 1084 $   \\ \hline
# cnpj\_entidade\_contratada          & $ 1   \pm 4   $      & $ 0.9 \pm 0.2 $  & $ 0.9 \pm 0.2 $ & $ 225  $   \\ \hline
# objeto\_contrato                    & $ 38  \pm 125 $      & $ 0.9 \pm 0.3 $  & $ 0.9 \pm 0.3 $ & $ 1039 $   \\ \hline
# valor\_contrato                     & $ 1   \pm 3   $      & $ 0.9 \pm 0.3 $  & $ 0.9 \pm 0.3 $ & $ 800  $   \\ \hline
# unidade\_orcamentaria               & $ 1   \pm 3   $      & $ 0.9 \pm 0.3 $  & $ 0.9 \pm 0.3 $ & $ 558  $   \\ \hline
# programa\_trabalho                  & $ 3   \pm 6   $      & $ 0.8 \pm 0.3 $  & $ 0.9 \pm 0.3 $ & $ 712  $   \\ \hline
# fonte\_recurso                      & $ 4   \pm 10  $      & $ 0.7 \pm 0.4 $  & $ 0.7 \pm 0.4 $ & $ 801  $   \\ \hline
# natureza\_despesa                   & $ 1   \pm 2   $      & $ 0.8 \pm 0.4 $  & $ 0.8 \pm 0.4 $ & $ 564  $   \\ \hline
# nota\_empenho                       & $ 1   \pm 4   $      & $ 0.9 \pm 0.3 $  & $ 0.9 \pm 0.3 $ & $ 680  $   \\ \hline
# vigencia\_contrato                  & $ 17  \pm 44  $      & $ 0.8 \pm 0.4 $  & $ 0.8 \pm 0.4 $ & $ 938  $   \\ \hline
# AVISO\_LICITACAO                    & $ 29  \pm 169 $      & $ 1.0 \pm 0.1 $  & $ 1.0 \pm 0.1 $ & $ 873  $   \\ \hline
# modalidade\_licitacao               & $ 2   \pm 4   $      & $ 0.9 \pm 0.3 $  & $ 0.9 \pm 0.3 $ & $ 830  $   \\ \hline
# numero\_licitacao                   & $ 3   \pm 51  $      & $ 0.9 \pm 0.3 $  & $ 0.9 \pm 0.3 $ & $ 1104 $   \\ \hline
# objeto\_licitacao                   & $ 31  \pm 90  $      & $ 0.9 \pm 0.3 $  & $ 0.9 \pm 0.3 $ & $ 951  $   \\ \hline
# tipo\_objeto                        & $ 4   \pm 6   $      & $ 0.7 \pm 0.5 $  & $ 0.7 \pm 0.5 $ & $ 873  $   \\ \hline
# orgao\_licitante                    & $ 6   \pm 17  $      & $ 0.7 \pm 0.4 $  & $ 0.7 \pm 0.4 $ & $ 774  $   \\ \hline
# valor\_estimado\_contratacao        & $ 0   \pm 2   $      & $ 1.0 \pm 0.2 $  & $ 1.0 \pm 0.2 $ & $ 560  $   \\ \hline
# data\_abertura\_licitacao           & $ 1   \pm 3   $      & $ 0.9 \pm 0.2 $  & $ 0.9 \pm 0.2 $ & $ 758  $   \\ \hline
# data\_escrito                       & $ 1   \pm 4   $      & $ 0.9 \pm 0.3 $  & $ 0.9 \pm 0.3 $ & $ 560  $   \\ \hline
# sistema\_compras                    & $ 2   \pm 7   $      & $ 0.9 \pm 0.3 $  & $ 0.9 \pm 0.3 $ & $ 900  $   \\ \hline
# codigo\_licitacao\_sistema\_compras & $ 0   \pm 2   $      & $ 0.9 \pm 0.2 $  & $ 0.9 \pm 0.2 $ & $ 611  $   \\ \hline
# nome\_responsavel                   & $ 1   \pm 5   $      & $ 1.0 \pm 0.2 $  & $ 0.9 \pm 0.2 $ & $ 1183 $   \\ \hline
# AVISO\_SUSPENSAO\_LICITACAO         & $ 27  \pm 204 $      & $ 1.0 \pm 0.2 $  & $ 1.0 \pm 0.2 $ & $ 84   $   \\ \hline
# EXTRATO\_ADITAMENTO\_CONTRATUAL     & $ 65  \pm 293 $      & $ 0.9 \pm 0.2 $  & $ 0.9 \pm 0.2 $ & $ 607  $   \\ \hline
# numero\_termo\_aditivo              & $ 1   \pm 5   $      & $ 0.9 \pm 0.2 $  & $ 0.9 \pm 0.2 $ & $ 628  $   \\ \hline
# objeto\_aditamento\_contratual      & $ 97  \pm 266 $      & $ 0.8 \pm 0.4 $  & $ 0.8 \pm 0.4 $ & $ 606  $   \\ \hline
# AVISO\_ANUL\_REV\_LICITACAO         & $ 34  \pm 165 $      & $ 1.0 \pm 0.2 $  & $ 1.0 \pm 0.2 $ & $ 30   $   \\ \hline
# identificacao\_ocorrencia           & $ 2   \pm 5   $      & $ 0.8 \pm 0.3 $  & $ 0.8 \pm 0.3 $ & $ 33   $   \\ \hline
# decisao\_tcdf                       & $ 23  \pm 37  $      & $ 0.2 \pm 0.3 $  & $ 0.4 \pm 0.4 $ & $ 19   $   \\ \hline
# cnpj\_orgao\_contratante            & $ 2   \pm 7   $      & $ 0.9 \pm 0.3 $  & $ 0.9 \pm 0.3 $ & $ 71   $   \\ \hline
# codigo\_siggo                       & $ 1   \pm 2   $      & $ 0.8 \pm 0.4 $  & $ 0.8 \pm 0.4 $ & $ 141  $   \\ \hline
# EXTRATO\_CONVENIO                   & $ 647 \pm 591 $      & $ 0.3 \pm 0.5 $  & $ 0.3 \pm 0.5 $ & $ 9    $   \\ \hline
# entidade\_convenente                & $ 21  \pm 18  $      & $ 0.2 \pm 0.4 $  & $ 0.2 \pm 0.4 $ & $ 10   $   \\ \hline
# cnpj\_entidade\_convenente          & $ 14  \pm 8   $      & $ 0.2 \pm 0.4 $  & $ 0.3 \pm 0.4 $ & $ 4    $   \\ \hline
# orgao\_concedente                   & $ 34  \pm 11  $      & $ 0.0 \pm 0.0 $  & $ 0.0 \pm 0.0 $ & $ 7    $   \\ \hline
# cnpj\_orgao\_concedente             & $ 18  \pm 0   $      & $ 0.0 \pm 0.0 $  & $ 0.0 \pm 0.0 $ & $ 1    $   \\ \hline
# objeto\_convenio                    & $ 111 \pm 179 $      & $ 0.5 \pm 0.5 $  & $ 0.5 \pm 0.5 $ & $ 11   $   \\ \hline
# vigencia\_convenio                  & $ 25  \pm 23  $      & $ 0.4 \pm 0.5 $  & $ 0.4 \pm 0.5 $ & $ 9    $   \\ \hline
# valor\_convenio                     & $ 4   \pm 6   $      & $ 0.7 \pm 0.5 $  & $ 0.7 \pm 0.5 $ & $ 3    $   \\ \hline
# data\_assinatura\_convenio          & $ 10  \pm 11  $      & $ 0.5 \pm 0.5 $  & $ 0.5 \pm 0.5 $ & $ 8    $   \\ \hline
# numero\_convenio                    & $ 7   \pm 5   $      & $ 0.2 \pm 0.4 $  & $ 0.2 \pm 0.4 $ & $ 9    $   \\ \hline
